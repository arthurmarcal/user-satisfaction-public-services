# %%
#!pip install tensorflow-gpu
# Downgrade 
#smart_open to 1.10.0 -> https://github.com/RaRe-Technologies/smart_open/issues/475
# python -m pip install -U smart_open==1.10.0

# %%
import os
# %load_ext tensorboard

# %%
###########################################
# How to make deterministic experiments?
###########################################

# Main Sources:
    # 1) https://github.com/NVIDIA/tensorflow-determinism
    # 2) https://pypi.org/project/tensorflow-determinism/#description
            # There are currently two main ways to access GPU-deterministic functionality in TensorFlow for most
            # deep learning applications. 
            # 2.1) The first way is to use an NVIDIA NGC TensorFlow container. - https://www.nvidia.com/en-us/gpu-cloud/containers/
            # 2.2. The second way is to use version 1.14, 1.15, or 2.0 of stock TensorFlow with GPU support, 
            #      plus the application of a patch supplied in this repo.

# # # Ensure Deterministic behaviour
import random
import numpy as np
import tensorflow as tf
os.environ['TF_DETERMINISTIC_OPS'] = '1'

# Now using tensorflow 2.1.0, so no need to patch
# from tfdeterminism import patch
#patch()

seed = 42
os.environ['PYTHONHASHSEED']=str(seed)
random.seed(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
############################################

# %%
# utils
from distutils.version import LooseVersion
from tqdm import tqdm_notebook
from datetime import datetime
from time import time

import warnings
import pickle
import gc
import sys
from json import dumps
import itertools
import re

# Data
import pandas as pd
import spacy

# Viz
import matplotlib.pyplot as plt

# Machine Learning
import tensorflow.keras.backend as K
from keras.preprocessing.text import one_hot, Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.layers import Input, Dropout, Bidirectional, LSTM, Flatten, Dense, Reshape
from keras.layers.embeddings import Embedding
from keras.models import Sequential, Model
from keras.optimizers import Adam
from keras.callbacks.callbacks import EarlyStopping
#from keras.callbacks import EarlyStopping, TensorBoard
#from tensorflow.keras.callbacks import EarlyStopping, TensorBoard
from keras_self_attention import SeqSelfAttention
from keras_multi_head import MultiHead, MultiHeadAttention

from sklearn.metrics import f1_score, classification_report
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# NLP Models
from gensim.models import Word2Vec, KeyedVectors
#w2v_models_path = 'C:/Users/arthu/Desktop/22032020 - Experimentos/05. Organizado/02. Notebooks/models/'
w2v_models_path = 'D:/Mestrado/Dissertação/07 .Dissertação Final/02. Experimentos/02. Word Embbedings/'
# Out:
# Using TensorFlow backend.

# %%
# METRICS
# def f1_score(y_true, y_pred):

#     # Count positive samples.
#     c1 = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
#     c2 = K.sum(K.round(K.clip(y_pred, 0, 1)))
#     c3 = K.sum(K.round(K.clip(y_true, 0, 1)))

# #     # If there are no true samples, fix the F1 score at 0.
# #     if c3 == 0:
# #         return 0

#     # How many selected items are relevant?
#     precision = c1 / c2

#     # How many relevant items are selected?
#     recall = c1 / c3

#     # Calculate f1_score
#     f1_score = 2 * (precision * recall) / (precision + recall)
#     return f1_score

# def recall(y_true, y_pred):

#     # Count positive samples.
#     c1 = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
#     c3 = K.sum(K.round(K.clip(y_true, 0, 1)))

# #     # If there are no true samples, fix the F1 score at 0.
# #     if c3 == 0:
# #         return 0

#     # How many relevant items are selected?
#     recall = c1 / c3
    
#     return recall


# def precision(y_true, y_pred):

#     # Count positive samples.
#     c1 = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
#     c2 = K.sum(K.round(K.clip(y_pred, 0, 1)))

#     # How many selected items are relevant?
#     precision = c1 / c2

#     return precision

# https://datascience.stackexchange.com/questions/45165/how-to-get-accuracy-f1-precision-and-recall-for-a-keras-model
def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %%
print('tf version: ' + tf.__version__)
# Out:
# tf version: 2.1.0-rc2

# %%
#Variables
current_exp = 'Atendimento-Balanced-Multiclass'
if 'Binary' in current_exp:
    binary = True
else:
    binary = False
    
base_path = 'C:/Users/arthu/Desktop/22032020 - Experimentos/05. Organizado/03. Datasets/' + current_exp
save_path = 'output'

sentence = 'req-text'
label = 'Atendimento'

x_train_file = 'X_train.csv'
y_train_file = 'y_train.csv'
x_test_file = 'X_test.csv'
y_test_file = 'y_test.csv'

#Load data
X_train = pd.read_csv(os.path.join(base_path, x_train_file), sep=';', encoding='utf-8')
y_train = pd.read_csv(os.path.join(base_path, y_train_file), sep=';', encoding='utf-8')
X_test = pd.read_csv(os.path.join(base_path, x_test_file), sep=';', encoding='utf-8')
y_test = pd.read_csv(os.path.join(base_path, y_test_file), sep=';', encoding='utf-8')

#Checking on data
print(X_train.columns)
print(X_train.shape)
print(y_train[label].value_counts())
print(y_test[label].value_counts())
# Out:
# Index(['pid', 'req-text', 'resp-text', '1funct-request', '2pronoun-request',
#        '3ppron-request', '4i-request', '5we-request', '6you-request',
#        '7shehe-request',
#        ...
#        '58home-response', '59money-response', '60relig-response',
#        '61death-response', '62assent-response', '63nonfl-response',
#        '64filler-response', 'Clareza', 'Atendimento', 'tempo_resposta'],
#       dtype='object', length=134)
# (6982, 134)
# 0    2367
# 1    2319
# 2    2296
# Name: Atendimento, dtype: int64
# 2    1029
# 1    1006
# 0     958
# Name: Atendimento, dtype: int64

# %%
# Keep only text columns
X_train.drop(columns=X_train.columns[2:], inplace=True)
X_test.drop(columns=X_train.columns[2:], inplace=True)

# %%
###################################################
X_train['sentence'] = X_train[sentence]
X_test['sentence'] = X_test[sentence]

y_train['label'] = y_train[label]
y_test['label'] = y_test[label]

##################################################################
# CUT DATAFRAME
# factor = 10000
# df = pd.concat([df[df.label=='1'][0:factor], df[df.label=='0'][0:factor]])
##################################################################

# Report the number of sentences.
print('Number of training sentences: {:,}\n'.format(X_train.shape[0]))

# Report the classes balance.
print('Classes distribuition: \n')
print(y_train[label].value_counts())

# Display 10 random rows from the data.
X_train.sample(10)
# Out:
# Number of training sentences: 6,982
#
# Classes distribuition:
#
# 0    2367
# 1    2319
# 2    2296
# Name: Atendimento, dtype: int64
#          pid                                           req-text  \
# 4119  414762  Gostaria de receber todas as informações refer...
# 3477  423065  Prezados, boa tarde! Solicito a gentileza de i...
# 4322  432042  1. PEDIDOS DE ACESSO À INFORMAÇÃO 1.1. PEDIDO ...
# 3349  553831  Considerando o posicionamento formal da DIPAR ...
# 469   546829  Prezados senhores, solicito para fins acadêmic...
# 538   467278  NÚMEROS DE 2017 DE CARGOS VAGOS DE SERVIDORES ...
# 6636  347965  Gostaria de saber quando serão convocados os a...
# 5820  445187              O pedido se encontra no anexo abaixo.
# 1047  565317  1.\tA Instituição utiliza sistema de cotas? 1....
# 1219  327624  Estou esperando a nomeação pelo concurso reali...
#
#                                                sentence
# 4119  Gostaria de receber todas as informações refer...
# 3477  Prezados, boa tarde! Solicito a gentileza de i...
# 4322  1. PEDIDOS DE ACESSO À INFORMAÇÃO 1.1. PEDIDO ...
# 3349  Considerando o posicionamento formal da DIPAR ...
# 469   Prezados senhores, solicito para fins acadêmic...
# 538   NÚMEROS DE 2017 DE CARGOS VAGOS DE SERVIDORES ...
# 6636  Gostaria de saber quando serão convocados os a...
# 5820              O pedido se encontra no anexo abaixo.
# 1047  1.\tA Instituição utiliza sistema de cotas? 1....
# 1219  Estou esperando a nomeação pelo concurso reali...

# %%
# Looking lengths
lengths = [X_train.sentence.apply(lambda x: len(x.split(' ')))]
perc =[.25, .50, .75, .80, .85, .90, .91, .92, .93, .94, .95, .96, .97, .98, .99] 
lengths[0].describe(percentiles = perc)
# Out:
# count    6982.000000
# mean       75.929390
# std        65.344213
# min         1.000000
# 25%        32.000000
# 50%        54.000000
# 75%        97.000000
# 80%       110.000000
# 85%       135.000000
# 90%       168.900000
# 91%       177.000000
# 92%       188.000000
# 93%       201.330000
# 94%       218.000000
# 95%       227.950000
# 96%       246.000000
# 97%       265.000000
# 98%       281.000000
# 99%       299.000000
# max       359.000000
# Name: sentence, dtype: float64

# %% [markdown]
# # w2v Model for Embedding Layer

# %%
#w2v_cbow_esic_model=KeyedVectors.load(os.path.join(w2v_models_path,'word2vec_sg_hs_DetalhamentoSolicitacao_all_sentences_128.model'))
w2v_cbow_nilc_model=KeyedVectors.load_word2vec_format(os.path.join(w2v_models_path,'cbow_s300.txt'))

# %%
pretrained_weights = w2v_cbow_nilc_model.wv.syn0
print(pretrained_weights.shape)
max_num_words = pretrained_weights.shape[0]
embed_size = pretrained_weights.shape[1]
# Out:
# (929606, 300)
# C:\Users\arthu\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """Entry point for launching an IPython kernel.
# C:\Users\arthu\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `syn0` (Attribute will be removed in 4.0.0, use self.vectors instead).
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# # Data Prep

# %%
max_length=128

# Define tokenizer and fit train data
t = Tokenizer(num_words=max_num_words)
t.fit_on_texts(X_train['sentence'].append(X_test['sentence']))
word_index = t.word_index
vocab_size = len(word_index) + 1
print('Found %s unique tokens.' % len(word_index))
    
def get_seqs(text):    
    sequences = t.texts_to_sequences(text)
    padded_sequences = pad_sequences(sequences, maxlen=max_length, padding='post')
    return padded_sequences
# Out:
# Found 34690 unique tokens.

# %%
# prepare target
def prepare_targets(y_train, y_test):
    le = LabelEncoder()
    le.fit(y_train)
    y_train_enc = le.transform(y_train)
    y_test_enc = le.transform(y_test)
    if binary:
        return y_train_enc, y_test_enc
    else:
        return pd.get_dummies(y_train_enc), pd.get_dummies(y_test_enc)

# %%
# X and Y
label_train, label_test = prepare_targets(y_train.label.values, y_test.label.values)
num_labels = len(set(label_train))
input_train = get_seqs(X_train.sentence)
input_test = get_seqs(X_test.sentence)

# %% [markdown]
# # Modeling

# %%
embedding_matrix = np.zeros((vocab_size, embed_size))
for word, i in t.word_index.items():
    try:
        embedding_vector = w2v_cbow_nilc_model.wv.__getitem__(word)
        if embedding_vector is not None:
            embedding_matrix[i] = embedding_vector
    # Words not in vocab -> Frequency less than 5 word
    except KeyError as e:
        print(e)
# Out:
# C:\Users\arthu\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:4: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   after removing the cwd from sys.path.
# "word '1' not in vocabulary"
# "word 'à' not in vocabulary"
# "word '2016' not in vocabulary"
# "word '2015' not in vocabulary"
# "word '2' not in vocabulary"
# "word '3' not in vocabulary"
# "word '2014' not in vocabulary"
# "word '2017' not in vocabulary"
# "word '–' not in vocabulary"
# "word '12' not in vocabulary"
# "word '4' not in vocabulary"
# "word '5' not in vocabulary"
# "word '10' not in vocabulary"
# "word '2013' not in vocabulary"
# "word '2011' not in vocabulary"
# "word '11' not in vocabulary"
# "word '2012' not in vocabulary"
# "word '01' not in vocabulary"
# "word '6' not in vocabulary"
# "word '7' not in vocabulary"
# "word '8' not in vocabulary"
# "word 'às' not in vocabulary"
# "word '06' not in vocabulary"
# "word '05' not in vocabulary"
# "word '2010' not in vocabulary"
# "word '9' not in vocabulary"
# "word '527' not in vocabulary"
# "word '30' not in vocabulary"
# "word '03' not in vocabulary"
# "word '18' not in vocabulary"
# "word '15' not in vocabulary"
# "word '02' not in vocabulary"
# "word '20' not in vocabulary"
# "word '14' not in vocabulary"
# "word '04' not in vocabulary"
# "word '09' not in vocabulary"
# "word '13' not in vocabulary"
# "word '07' not in vocabulary"
# "word '16' not in vocabulary"
# "word '2009' not in vocabulary"
# "word '08' not in vocabulary"
# "word '31' not in vocabulary"
# "word '21' not in vocabulary"
# "word '17' not in vocabulary"
# "word '0001' not in vocabulary"
# "word '22' not in vocabulary"
# "word '2006' not in vocabulary"
# "word '2007' not in vocabulary"
# "word '23' not in vocabulary"
# "word '2008' not in vocabulary"
# "word '2005' not in vocabulary"
# "word '25' not in vocabulary"
# "word '1º' not in vocabulary"
# "word '2000' not in vocabulary"
# "word '19' not in vocabulary"
# "word '26' not in vocabulary"
# "word '24' not in vocabulary"
# "word '2004' not in vocabulary"
# "word '29' not in vocabulary"
# "word '2003' not in vocabulary"
# "word '28' not in vocabulary"
# "word '48500' not in vocabulary"
# "word '2001' not in vocabulary"
# "word '2002' not in vocabulary"
# "word '2º' not in vocabulary"
# "word '27' not in vocabulary"
# "word '50' not in vocabulary"
# "word '60' not in vocabulary"
# "word '90' not in vocabulary"
# "word '3º' not in vocabulary"
# "word '100' not in vocabulary"
# "word '5º' not in vocabulary"
# "word 'brasemb' not in vocabulary"
# "word '1993' not in vocabulary"
# "word 'ebtt' not in vocabulary"
# "word '1997' not in vocabulary"
# "word '1996' not in vocabulary"
# "word '61' not in vocabulary"
# "word '40' not in vocabulary"
# "word '1990' not in vocabulary"
# "word '87' not in vocabulary"
# "word '32' not in vocabulary"
# "word '37' not in vocabulary"
# "word 'megp' not in vocabulary"
# "word '”' not in vocabulary"
# "word '48' not in vocabulary"
# "word '1999' not in vocabulary"
# "word '112' not in vocabulary"
# "word '41' not in vocabulary"
# "word '34' not in vocabulary"
# "word '99' not in vocabulary"
# "word '51' not in vocabulary"
# "word '2018' not in vocabulary"
# "word '724' not in vocabulary"
# "word '70' not in vocabulary"
# "word '“contrato' not in vocabulary"
# "word '92' not in vocabulary"
# "word '89' not in vocabulary"
# "word '4º' not in vocabulary"
# "word '91' not in vocabulary"
# "word 'disit' not in vocabulary"
# "word '80' not in vocabulary"
# "word '1995' not in vocabulary"
# "word '1ª' not in vocabulary"
# "word '001' not in vocabulary"
# "word '46' not in vocabulary"
# "word '104' not in vocabulary"
# "word '43' not in vocabulary"
# "word '35' not in vocabulary"
# "word '93' not in vocabulary"
# "word '2ª' not in vocabulary"
# "word '76' not in vocabulary"
# "word '33' not in vocabulary"
# "word '97' not in vocabulary"
# "word '45' not in vocabulary"
# "word '7º' not in vocabulary"
# "word '65' not in vocabulary"
# "word '1991' not in vocabulary"
# "word '55' not in vocabulary"
# "word '1988' not in vocabulary"
# "word '“' not in vocabulary"
# "word '818' not in vocabulary"
# "word '49' not in vocabulary"
# "word '36' not in vocabulary"
# "word '8º' not in vocabulary"
# "word '1998' not in vocabulary"
# "word '835' not in vocabulary"
# "word '98' not in vocabulary"
# "word 'siconv' not in vocabulary"
# "word 'siasgweb' not in vocabulary"
# "word '500' not in vocabulary"
# "word '47' not in vocabulary"
# "word 'vigentes”' not in vocabulary"
# "word '300' not in vocabulary"
# "word '39' not in vocabulary"
# "word '38' not in vocabulary"
# "word '53' not in vocabulary"
# "word 'qrsta' not in vocabulary"
# "word 'igovti' not in vocabulary"
# "word '74' not in vocabulary"
# "word 'gespública' not in vocabulary"
# "word '216' not in vocabulary"
# "word '62' not in vocabulary"
# "word '54' not in vocabulary"
# "word '42' not in vocabulary"
# "word '105' not in vocabulary"
# "word '6º' not in vocabulary"
# "word '200' not in vocabulary"
# "word '091' not in vocabulary"
# "word '95' not in vocabulary"
# "word '15414' not in vocabulary"
# "word '81' not in vocabulary"
# "word '600' not in vocabulary"
# "word '77' not in vocabulary"
# "word '1°' not in vocabulary"
# "word 'c3' not in vocabulary"
# "word '78' not in vocabulary"
# "word '52' not in vocabulary"
# "word '73' not in vocabulary"
# "word '59' not in vocabulary"
# "word '85' not in vocabulary"
# "word '94' not in vocabulary"
# "word '116' not in vocabulary"
# "word '88' not in vocabulary"
# "word '1987' not in vocabulary"
# "word '321' not in vocabulary"
# "word '711' not in vocabulary"
# "word '58' not in vocabulary"
# "word '101' not in vocabulary"
# "word '67' not in vocabulary"
# "word '1994' not in vocabulary"
# "word 'rj2014' not in vocabulary"
# "word '015' not in vocabulary"
# "word '64' not in vocabulary"
# "word '63' not in vocabulary"
# "word '320' not in vocabulary"
# "word '82' not in vocabulary"
# "word '84' not in vocabulary"
# "word '79' not in vocabulary"
# "word '56' not in vocabulary"
# "word '96' not in vocabulary"
# "word '224' not in vocabulary"
# "word '120' not in vocabulary"
# "word '25351' not in vocabulary"
# "word '72' not in vocabulary"
# "word '71' not in vocabulary"
# "word '00045' not in vocabulary"
# "word 'consbras' not in vocabulary"
# "word '261' not in vocabulary"
# "word '1985' not in vocabulary"
# "word '44' not in vocabulary"
# "word '1980' not in vocabulary"
# "word '75' not in vocabulary"
# "word 'profiap' not in vocabulary"
# "word '851' not in vocabulary"
# "word '524' not in vocabulary"
# "word '378' not in vocabulary"
# "word '1992' not in vocabulary"
# "word '86' not in vocabulary"
# "word '83' not in vocabulary"
# "word '1llrnsdevut829ym1' not in vocabulary"
# "word '“pesquisa”' not in vocabulary"
# "word '150' not in vocabulary"
# "word '394' not in vocabulary"
# "word '57' not in vocabulary"
# "word '69' not in vocabulary"
# "word '66' not in vocabulary"
# "word '48513' not in vocabulary"
# "word '705' not in vocabulary"
# "word '140' not in vocabulary"
# "word '1978' not in vocabulary"
# "word 'dallapicula' not in vocabulary"
# "word '002' not in vocabulary"
# "word 'raint' not in vocabulary"
# "word '288' not in vocabulary"
# "word '029' not in vocabulary"
# "word '180' not in vocabulary"
# "word '68' not in vocabulary"
# "word '008' not in vocabulary"
# "word '130' not in vocabulary"
# "word '400' not in vocabulary"
# "word '546' not in vocabulary"
# "word 'gabmin' not in vocabulary"
# "word 'segrt' not in vocabulary"
# "word 'fanara' not in vocabulary"
# "word '195' not in vocabulary"
# "word '12527' not in vocabulary"
# "word 'vigente”' not in vocabulary"
# "word '9º' not in vocabulary"
# "word 'srrf08' not in vocabulary"
# "word '666' not in vocabulary"
# "word '01420' not in vocabulary"
# "word '“as' not in vocabulary"
# "word 'mestrandas' not in vocabulary"
# "word '303' not in vocabulary"
# "word '“o' not in vocabulary"
# "word '1983' not in vocabulary"
# "word '“e”' not in vocabulary"
# "word '3ª' not in vocabulary"
# "word '013' not in vocabulary"
# "word '392' not in vocabulary"
# "word 'iagp' not in vocabulary"
# "word '128' not in vocabulary"
# "word '005' not in vocabulary"
# "word '004' not in vocabulary"
# "word '1989' not in vocabulary"
# "word 'protocolointegrado' not in vocabulary"
# "word '824' not in vocabulary"
# "word '“inclusão' not in vocabulary"
# "word 'afirmativas”' not in vocabulary"
# "word '“proposta”' not in vocabulary"
# "word '257' not in vocabulary"
# "word '800' not in vocabulary"
# "word '003' not in vocabulary"
# "word 'uasg' not in vocabulary"
# "word '135' not in vocabulary"
# "word '959' not in vocabulary"
# "word '1970' not in vocabulary"
# "word '17944' not in vocabulary"
# "word 'transpanorama' not in vocabulary"
# "word '–dg' not in vocabulary"
# "word '04972' not in vocabulary"
# "word '02001' not in vocabulary"
# "word '2o' not in vocabulary"
# "word 'vida”' not in vocabulary"
# "word '612' not in vocabulary"
# "word '525' not in vocabulary"
# "word '006' not in vocabulary"
# "word 'macropolo' not in vocabulary"
# "word '327' not in vocabulary"
# "word '149' not in vocabulary"
# "word '1986' not in vocabulary"
# "word '290' not in vocabulary"
# "word '1984' not in vocabulary"
# "word 'ifse' not in vocabulary"
# "word '23480' not in vocabulary"
# "word '020' not in vocabulary"
# "word '094' not in vocabulary"
# "word '1950' not in vocabulary"
# "word 'cgrh' not in vocabulary"
# "word '2016106186' not in vocabulary"
# "word 'passeggi' not in vocabulary"
# "word '01500' not in vocabulary"
# "word 'ckfinder' not in vocabulary"
# "word '2019' not in vocabulary"
# "word '04967' not in vocabulary"
# "word '0002' not in vocabulary"
# "word '286' not in vocabulary"
# "word 'planinvesti' not in vocabulary"
# "word '174' not in vocabulary"
# "word '3o' not in vocabulary"
# "word '0800' not in vocabulary"
# "word 'zopacas' not in vocabulary"
# "word 'rj2013' not in vocabulary"
# "word '090' not in vocabulary"
# "word 'hidroweb' not in vocabulary"
# "word '1959' not in vocabulary"
# "word 'convenente' not in vocabulary"
# "word '381' not in vocabulary"
# "word '270' not in vocabulary"
# "word '23105' not in vocabulary"
# "word 'ifsertão' not in vocabulary"
# "word 'inacumulável' not in vocabulary"
# "word '810' not in vocabulary"
# "word 'pronas' not in vocabulary"
# "word 'acessoainformacao' not in vocabulary"
# "word '354' not in vocabulary"
# "word '217' not in vocabulary"
# "word '1976' not in vocabulary"
# "word '250' not in vocabulary"
# "word '233' not in vocabulary"
# "word '111' not in vocabulary"
# "word 'gf8n33k' not in vocabulary"
# "word '225' not in vocabulary"
# "word '§6º' not in vocabulary"
# "word '2523' not in vocabulary"
# "word '158' not in vocabulary"
# "word '“governo' not in vocabulary"
# "word 'públicas”' not in vocabulary"
# "word 'marianasp' not in vocabulary"
# "word '1o' not in vocabulary"
# "word '177' not in vocabulary"
# "word '8112' not in vocabulary"
# "word 'cosit' not in vocabulary"
# "word '278' not in vocabulary"
# "word '988' not in vocabulary"
# "word '144' not in vocabulary"
# "word '50300' not in vocabulary"
# "word '213' not in vocabulary"
# "word 'srrf' not in vocabulary"
# "word '018' not in vocabulary"
# "word '51402' not in vocabulary"
# "word 'resguardadas”' not in vocabulary"
# "word 'consultaesic' not in vocabulary"
# "word 'arquivosrelatorios' not in vocabulary"
# "word 'pedidosrespostas' not in vocabulary"
# "word 'exportacao' not in vocabulary"
# "word '875' not in vocabulary"
# "word '048' not in vocabulary"
# "word 'sureg' not in vocabulary"
# "word '153' not in vocabulary"
# "word '136' not in vocabulary"
# "word '2020' not in vocabulary"
# "word 'gsiste' not in vocabulary"
# "word '700' not in vocabulary"
# "word '241' not in vocabulary"
# "word '107' not in vocabulary"
# "word 'mcsfonseca' not in vocabulary"
# "word '480' not in vocabulary"
# "word '143' not in vocabulary"
# "word '010' not in vocabulary"
# "word '164' not in vocabulary"
# "word '115' not in vocabulary"
# "word '10438' not in vocabulary"
# "word '10676' not in vocabulary"
# "word '160' not in vocabulary"
# "word '347' not in vocabulary"
# "word '315' not in vocabulary"
# "word '038' not in vocabulary"
# "word '•solução' not in vocabulary"
# "word '240' not in vocabulary"
# "word '475' not in vocabulary"
# "word '00190' not in vocabulary"
# "word '125' not in vocabulary"
# "word '707' not in vocabulary"
# "word '280' not in vocabulary"
# "word '022' not in vocabulary"
# "word '1979' not in vocabulary"
# "word '784' not in vocabulary"
# "word '360' not in vocabulary"
# "word '275' not in vocabulary"
# "word '5ª' not in vocabulary"
# "word '234' not in vocabulary"
# "word '09009' not in vocabulary"
# "word '242' not in vocabulary"
# "word 'pcctae' not in vocabulary"
# "word 'unexpo' not in vocabulary"
# "word 'nº1' not in vocabulary"
# "word '5o' not in vocabulary"
# "word 'cgpae' not in vocabulary"
# "word '7ª' not in vocabulary"
# "word '957' not in vocabulary"
# "word '889' not in vocabulary"
# "word 'unifilar' not in vocabulary"
# "word '792' not in vocabulary"
# "word '159' not in vocabulary"
# "word 'pgpe' not in vocabulary"
# "word '277' not in vocabulary"
# "word '033' not in vocabulary"
# "word '011' not in vocabulary"
# "word '171' not in vocabulary"
# "word '369' not in vocabulary"
# "word 'delbrasonu' not in vocabulary"
# "word '330' not in vocabulary"
# "word '110' not in vocabulary"
# "word '58701' not in vocabulary"
# "word '254' not in vocabulary"
# "word '170' not in vocabulary"
# "word '982' not in vocabulary"
# "word '145' not in vocabulary"
# "word '027' not in vocabulary"
# "word '351' not in vocabulary"
# "word '050' not in vocabulary"
# "word '040' not in vocabulary"
# "word '1975' not in vocabulary"
# "word '402' not in vocabulary"
# "word '97350' not in vocabulary"
# "word '7775' not in vocabulary"
# "word '021' not in vocabulary"
# "word '10º' not in vocabulary"
# "word '613' not in vocabulary"
# "word '207' not in vocabulary"
# "word '750' not in vocabulary"
# "word '167' not in vocabulary"
# "word '267' not in vocabulary"
# "word '103' not in vocabulary"
# "word 'isencao' not in vocabulary"
# "word 'www2' not in vocabulary"
# "word '123' not in vocabulary"
# "word '134' not in vocabulary"
# "word '298' not in vocabulary"
# "word '759' not in vocabulary"
# "word '25759' not in vocabulary"
# "word '016' not in vocabulary"
# "word '3°' not in vocabulary"
# "word 'pdti' not in vocabulary"
# "word '156' not in vocabulary"
# "word '5912' not in vocabulary"
# "word '989' not in vocabulary"
# "word 'l2' not in vocabulary"
# "word 'gdasus' not in vocabulary"
# "word 'dsic' not in vocabulary"
# "word '85070068' not in vocabulary"
# "word '117' not in vocabulary"
# "word '148' not in vocabulary"
# "word 'coreg' not in vocabulary"
# "word '“a' not in vocabulary"
# "word '25000' not in vocabulary"
# "word 'sefip' not in vocabulary"
# "word '40h' not in vocabulary"
# "word '590' not in vocabulary"
# "word '364' not in vocabulary"
# "word '133' not in vocabulary"
# "word '212' not in vocabulary"
# "word '2°' not in vocabulary"
# "word '122' not in vocabulary"
# "word '208' not in vocabulary"
# "word '009' not in vocabulary"
# "word '350' not in vocabulary"
# "word '404' not in vocabulary"
# "word '017' not in vocabulary"
# "word '03000' not in vocabulary"
# "word '186' not in vocabulary"
# "word 'neabi' not in vocabulary"
# "word '971' not in vocabulary"
# "word '047' not in vocabulary"
# "word 'slie' not in vocabulary"
# "word '02501' not in vocabulary"
# "word 'mg01' not in vocabulary"
# "word '48000' not in vocabulary"
# "word '301' not in vocabulary"
# "word '202' not in vocabulary"
# "word '596' not in vocabulary"
# "word '870' not in vocabulary"
# "word 'qtd' not in vocabulary"
# "word '1960' not in vocabulary"
# "word '450' not in vocabulary"
# "word 'solicitacao' not in vocabulary"
# "word '680' not in vocabulary"
# "word '50600' not in vocabulary"
# "word '“requerimentos”' not in vocabulary"
# "word 'uninversidade' not in vocabulary"
# "word '“alternativa' not in vocabulary"
# "word '550' not in vocabulary"
# "word '539' not in vocabulary"
# "word '239' not in vocabulary"
# "word '313' not in vocabulary"
# "word '228' not in vocabulary"
# "word '314' not in vocabulary"
# "word '142' not in vocabulary"
# "word '121' not in vocabulary"
# "word '850' not in vocabulary"
# "word '287' not in vocabulary"
# "word '900' not in vocabulary"
# "word '102' not in vocabulary"
# "word 'renainf' not in vocabulary"
# "word '23419' not in vocabulary"
# "word '2030' not in vocabulary"
# "word '23074' not in vocabulary"
# "word '334' not in vocabulary"
# "word 'sivep' not in vocabulary"
# "word '012' not in vocabulary"
# "word 'fmiee' not in vocabulary"
# "word '990' not in vocabulary"
# "word 'ccivil' not in vocabulary"
# "word 'cgti' not in vocabulary"
# "word '168' not in vocabulary"
# "word '1982' not in vocabulary"
# "word '365' not in vocabulary"
# "word '1253873' not in vocabulary"
# "word 'scdp' not in vocabulary"
# "word 'coecs' not in vocabulary"
# "word 'braseuropa' not in vocabulary"
# "word 'pebf' not in vocabulary"
# "word '5208707' not in vocabulary"
# "word '9ªrf' not in vocabulary"
# "word 'naoreemb' not in vocabulary"
# "word 'cgdc' not in vocabulary"
# "word '5000' not in vocabulary"
# "word 'rreo' not in vocabulary"
# "word '147' not in vocabulary"
# "word 'procondel' not in vocabulary"
# "word '226' not in vocabulary"
# "word '880' not in vocabulary"
# "word '396' not in vocabulary"
# "word 'iffar' not in vocabulary"
# "word '059' not in vocabulary"
# "word '806' not in vocabulary"
# "word '1977' not in vocabulary"
# "word '1972' not in vocabulary"
# "word 'assec' not in vocabulary"
# "word '462' not in vocabulary"
# "word '124' not in vocabulary"
# "word '685' not in vocabulary"
# "word '044' not in vocabulary"
# "word '084' not in vocabulary"
# "word '00350' not in vocabulary"
# "word 'ccomp' not in vocabulary"
# "word '493' not in vocabulary"
# "word 'g56' not in vocabulary"
# "word 'm65' not in vocabulary"
# "word '1968' not in vocabulary"
# "word '310' not in vocabulary"
# "word '913' not in vocabulary"
# "word '190' not in vocabulary"
# "word '209' not in vocabulary"
# "word '260' not in vocabulary"
# "word '196' not in vocabulary"
# "word '437' not in vocabulary"
# "word 'prezad' not in vocabulary"
# "word 'perfilgovpessoal' not in vocabulary"
# "word '061' not in vocabulary"
# "word '452' not in vocabulary"
# "word 'vilane' not in vocabulary"
# "word '1969' not in vocabulary"
# "word '580' not in vocabulary"
# "word 'àqueles' not in vocabulary"
# "word '502' not in vocabulary"
# "word '1939' not in vocabulary"
# "word '1945' not in vocabulary"
# "word 'srrf07' not in vocabulary"
# "word '080' not in vocabulary"
# "word 'neab' not in vocabulary"
# "word 'psicosanna' not in vocabulary"
# "word '445' not in vocabulary"
# "word '316' not in vocabulary"
# "word '772' not in vocabulary"
# "word 'sigaa' not in vocabulary"
# "word '“x”' not in vocabulary"
# "word '4o' not in vocabulary"
# "word 'cogep' not in vocabulary"
# "word '322' not in vocabulary"
# "word '37º' not in vocabulary"
# "word '“art' not in vocabulary"
# "word '246' not in vocabulary"
# "word '262' not in vocabulary"
# "word '291' not in vocabulary"
# "word '349' not in vocabulary"
# "word '855' not in vocabulary"
# "word '253' not in vocabulary"
# "word '118' not in vocabulary"
# "word '185' not in vocabulary"
# "word 'portalsaude' not in vocabulary"
# "word 'a3p' not in vocabulary"
# "word '137' not in vocabulary"
# "word '1966' not in vocabulary"
# "word 'debitos' not in vocabulary"
# "word '579' not in vocabulary"
# "word '0059' not in vocabulary"
# "word '295' not in vocabulary"
# "word '1967' not in vocabulary"
# "word '024' not in vocabulary"
# "word 'a3o' not in vocabulary"
# "word '161' not in vocabulary"
# "word '109' not in vocabulary"
# "word '328' not in vocabulary"
# "word '131' not in vocabulary"
# "word '169' not in vocabulary"
# "word 'pdtic' not in vocabulary"
# "word '154' not in vocabulary"
# "word '2153' not in vocabulary"
# "word '987' not in vocabulary"
# "word 'conres' not in vocabulary"
# "word 'anuídos' not in vocabulary"
# "word '5911' not in vocabulary"
# "word '90028' not in vocabulary"
# "word '5214507' not in vocabulary"
# "word 'progesp' not in vocabulary"
# "word 'reemb' not in vocabulary"
# "word 'desptel' not in vocabulary"
# "word '874' not in vocabulary"
# "word '031' not in vocabulary"
# "word '478' not in vocabulary"
# "word '21000' not in vocabulary"
# "word '890' not in vocabulary"
# "word '401' not in vocabulary"
# "word 'spassu' not in vocabulary"
# "word '865' not in vocabulary"
# "word '4202' not in vocabulary"
# "word '201' not in vocabulary"
# "word 'pfvs' not in vocabulary"
# "word '151' not in vocabulary"
# "word '294' not in vocabulary"
# "word '387' not in vocabulary"
# "word '541' not in vocabulary"
# "word '380' not in vocabulary"
# "word '573' not in vocabulary"
# "word '“sigiloso”' not in vocabulary"
# "word 'www4' not in vocabulary"
# "word 'cgpert' not in vocabulary"
# "word '474' not in vocabulary"
# "word 'pfaneel' not in vocabulary"
# "word '293' not in vocabulary"
# "word '512' not in vocabulary"
# "word '726' not in vocabulary"
# "word 'brasil”' not in vocabulary"
# "word '227' not in vocabulary"
# "word '23228' not in vocabulary"
# "word '030' not in vocabulary"
# "word '138' not in vocabulary"
# "word '13º' not in vocabulary"
# "word 'plhis' not in vocabulary"
# "word 'mcidades' not in vocabulary"
# "word 'asfoc' not in vocabulary"
# "word '552' not in vocabulary"
# "word '715' not in vocabulary"
# "word '3515' not in vocabulary"
# "word '459' not in vocabulary"
# "word '376' not in vocabulary"
# "word '655' not in vocabulary"
# "word '526' not in vocabulary"
# "word 'dgpm' not in vocabulary"
# "word '881' not in vocabulary"
# "word '940' not in vocabulary"
# "word 'qtde' not in vocabulary"
# "word '774' not in vocabulary"
# "word 'srrf05' not in vocabulary"
# "word '“strictu' not in vocabulary"
# "word 'sensu”' not in vocabulary"
# "word '037' not in vocabulary"
# "word '“poderá' not in vocabulary"
# "word 'habilitados”' not in vocabulary"
# "word 'sigepe' not in vocabulary"
# "word '179' not in vocabulary"
# "word '902' not in vocabulary"
# "word '019' not in vocabulary"
# "word '359' not in vocabulary"
# "word '191' not in vocabulary"
# "word '033513' not in vocabulary"
# "word '1981' not in vocabulary"
# "word 'denop' not in vocabulary"
# "word '113' not in vocabulary"
# "word '691' not in vocabulary"
# "word '498' not in vocabulary"
# "word 'reven' not in vocabulary"
# "word '497' not in vocabulary"
# "word '244' not in vocabulary"
# "word 'cepim' not in vocabulary"
# "word '302' not in vocabulary"
# "word '505' not in vocabulary"
# "word 'pls’s' not in vocabulary"
# "word 'semiestruturado' not in vocabulary"
# "word '1964' not in vocabulary"
# "word '25c3' not in vocabulary"
# "word 'proinfancia' not in vocabulary"
# "word '056' not in vocabulary"
# "word 'propg' not in vocabulary"
# "word '593' not in vocabulary"
# "word 'licitacoes' not in vocabulary"
# "word '106' not in vocabulary"
# "word '§2º' not in vocabulary"
# "word '790' not in vocabulary"
# "word '218' not in vocabulary"
# "word 'dlllb' not in vocabulary"
# "word '5°' not in vocabulary"
# "word 'egti' not in vocabulary"
# "word '§1º' not in vocabulary"
# "word 'sirgas2000' not in vocabulary"
# "word '1971' not in vocabulary"
# "word '433' not in vocabulary"
# "word 'tbns' not in vocabulary"
# "word 'depes' not in vocabulary"
# "word '414' not in vocabulary"
# "word '576' not in vocabulary"
# "word '155' not in vocabulary"
# "word '326' not in vocabulary"
# "word '555' not in vocabulary"
# "word '141' not in vocabulary"
# "word '035' not in vocabulary"
# "word '176' not in vocabulary"
# "word '025839' not in vocabulary"
# "word '52000' not in vocabulary"
# "word '199' not in vocabulary"
# "word '299' not in vocabulary"
# "word 'letec' not in vocabulary"
# "word '481' not in vocabulary"
# "word '248' not in vocabulary"
# "word '08657' not in vocabulary"
# "word '02000' not in vocabulary"
# "word '422' not in vocabulary"
# "word '383' not in vocabulary"
# "word '036' not in vocabulary"
# "word '776' not in vocabulary"
# "word 'delbrasgen' not in vocabulary"
# "word '444' not in vocabulary"
# "word 'mercopampa' not in vocabulary"
# "word '329' not in vocabulary"
# "word '346' not in vocabulary"
# "word 'vigep' not in vocabulary"
# "word '194' not in vocabulary"
# "word '243' not in vocabulary"
# "word '042' not in vocabulary"
# "word '58000' not in vocabulary"
# "word '057' not in vocabulary"
# "word 'preposta' not in vocabulary"
# "word 'z56' not in vocabulary"
# "word 'reop' not in vocabulary"
# "word 'prda' not in vocabulary"
# "word '918' not in vocabulary"
# "word '418' not in vocabulary"
# "word '06606941' not in vocabulary"
# "word 'sspba' not in vocabulary"
# "word '2110269' not in vocabulary"
# "word '10188' not in vocabulary"
# "word '055' not in vocabulary"
# "word '146' not in vocabulary"
# "word '041' not in vocabulary"
# "word '469' not in vocabulary"
# "word 'contribuicao' not in vocabulary"
# "word 'soster' not in vocabulary"
# "word '1331' not in vocabulary"
# "word 'siscebas' not in vocabulary"
# "word 'ciisc' not in vocabulary"
# "word '536' not in vocabulary"
# "word '429' not in vocabulary"
# "word 'públicos”' not in vocabulary"
# "word 'decdp' not in vocabulary"
# "word 'renafor' not in vocabulary"
# "word '08620' not in vocabulary"
# "word '152' not in vocabulary"
# "word 'trf1' not in vocabulary"
# "word 'remborso' not in vocabulary"
# "word 'gepes' not in vocabulary"
# "word '23411' not in vocabulary"
# "word '220' not in vocabulary"
# "word '357' not in vocabulary"
# "word '575' not in vocabulary"
# "word '578' not in vocabulary"
# "word '188' not in vocabulary"
# "word '503' not in vocabulary"
# "word 'manpes' not in vocabulary"
# "word '645' not in vocabulary"
# "word '331' not in vocabulary"
# "word '845' not in vocabulary"
# "word '438' not in vocabulary"
# "word '132' not in vocabulary"
# "word 'edenivan' not in vocabulary"
# "word '075' not in vocabulary"
# "word '605' not in vocabulary"
# "word '677' not in vocabulary"
# "word '068' not in vocabulary"
# "word '3066' not in vocabulary"
# "word '385' not in vocabulary"
# "word 'àquelas' not in vocabulary"
# "word '007' not in vocabulary"
# "word '416' not in vocabulary"
# "word '335' not in vocabulary"
# "word 'ppgci' not in vocabulary"
# "word '1930' not in vocabulary"
# "word '259' not in vocabulary"
# "word 'mancod' not in vocabulary"
# "word '222' not in vocabulary"
# "word 'mediotec' not in vocabulary"
# "word '073' not in vocabulary"
# "word '069' not in vocabulary"
# "word '086' not in vocabulary"
# "word '743' not in vocabulary"
# "word '470' not in vocabulary"
# "word '3000' not in vocabulary"
# "word '025' not in vocabulary"
# "word '052' not in vocabulary"
# "word '162' not in vocabulary"
# "word '304' not in vocabulary"
# "word 'gilog' not in vocabulary"
# "word '348' not in vocabulary"
# "word '826' not in vocabulary"
# "word '793' not in vocabulary"
# "word 'inscriçao' not in vocabulary"
# "word '332' not in vocabulary"
# "word '944' not in vocabulary"
# "word 'rarh' not in vocabulary"
# "word '766' not in vocabulary"
# "word 'pccs2008' not in vocabulary"
# "word '0493' not in vocabulary"
# "word '911' not in vocabulary"
# "word '7922' not in vocabulary"
# "word 'pcd's' not in vocabulary"
# "word '7234' not in vocabulary"
# "word 'sgpa' not in vocabulary"
# "word '867' not in vocabulary"
# "word '786' not in vocabulary"
# "word 'cprod' not in vocabulary"
# "word '500m' not in vocabulary"
# "word '129' not in vocabulary"
# "word '1931' not in vocabulary"
# "word '324' not in vocabulary"
# "word '175' not in vocabulary"
# "word '9000' not in vocabulary"
# "word '358' not in vocabulary"
# "word 'sindiedutec' not in vocabulary"
# "word '074' not in vocabulary"
# "word '389' not in vocabulary"
# "word '192' not in vocabulary"
# "word '1974' not in vocabulary"
# "word 'prosavana' not in vocabulary"
# "word '13ª' not in vocabulary"
# "word 'ctpcc' not in vocabulary"
# "word '308' not in vocabulary"
# "word '682' not in vocabulary"
# "word 'oglobo' not in vocabulary"
# "word '§3º' not in vocabulary"
# "word '656' not in vocabulary"
# "word '529' not in vocabulary"
# "word '4840' not in vocabulary"
# "word '1008' not in vocabulary"
# "word 'rarh1”' not in vocabulary"
# "word 'renave' not in vocabulary"
# "word '975' not in vocabulary"
# "word '996527177' not in vocabulary"
# "word '0135' not in vocabulary"
# "word '108' not in vocabulary"
# "word '540' not in vocabulary"
# "word '215' not in vocabulary"
# "word 'g1' not in vocabulary"
# "word '564' not in vocabulary"
# "word '231' not in vocabulary"
# "word '888' not in vocabulary"
# "word '853' not in vocabulary"
# "word 'br040' not in vocabulary"
# "word 'autoseg' not in vocabulary"
# "word 'a7' not in vocabulary"
# "word 'munici\xadpio' not in vocabulary"
# "word '616' not in vocabulary"
# "word 'sesmts' not in vocabulary"
# "word '19º' not in vocabulary"
# "word '211' not in vocabulary"
# "word '039' not in vocabulary"
# "word '166' not in vocabulary"
# "word '728' not in vocabulary"
# "word '20h' not in vocabulary"
# "word '214' not in vocabulary"
# "word '789' not in vocabulary"
# "word '409' not in vocabulary"
# "word 'bdgd' not in vocabulary"
# "word 'cerat' not in vocabulary"
# "word '01390' not in vocabulary"
# "word '391' not in vocabulary"
# "word '455' not in vocabulary"
# "word '072' not in vocabulary"
# "word '520' not in vocabulary"
# "word '5050' not in vocabulary"
# "word '428' not in vocabulary"
# "word '012578' not in vocabulary"
# "word '356' not in vocabulary"
# "word 'censo2010' not in vocabulary"
# "word '848' not in vocabulary"
# "word '739' not in vocabulary"
# "word '184' not in vocabulary"
# "word '947' not in vocabulary"
# "word 'gdac' not in vocabulary"
# "word '601' not in vocabulary"
# "word '319' not in vocabulary"
# "word '245' not in vocabulary"
# "word '4ª' not in vocabulary"
# "word '6ª' not in vocabulary"
# "word '563' not in vocabulary"
# "word 'pecfaz' not in vocabulary"
# "word 'diapc' not in vocabulary"
# "word 'acfis' not in vocabulary"
# "word '1962' not in vocabulary"
# "word '014' not in vocabulary"
# "word '1078' not in vocabulary"
# "word 'vyndaquel' not in vocabulary"
# "word '114' not in vocabulary"
# "word '594' not in vocabulary"
# "word '268' not in vocabulary"
# "word 'p102' not in vocabulary"
# "word '770' not in vocabulary"
# "word '9h' not in vocabulary"
# "word '5w2h' not in vocabulary"
# "word '482' not in vocabulary"
# "word 'correg' not in vocabulary"
# "word 'conubes' not in vocabulary"
# "word 'tae's' not in vocabulary"
# "word 'de2006' not in vocabulary"
# "word '339' not in vocabulary"
# "word 'macrotemas' not in vocabulary"
# "word '034' not in vocabulary"
# "word '182' not in vocabulary"
# "word '722' not in vocabulary"
# "word 'marvile' not in vocabulary"
# "word '430' not in vocabulary"
# "word '6022' not in vocabulary"
# "word 'sisfauna' not in vocabulary"
# "word '093' not in vocabulary"
# "word '01506' not in vocabulary"
# "word 'inepdata' not in vocabulary"
# "word '54170' not in vocabulary"
# "word 'asparmig' not in vocabulary"
# "word '829' not in vocabulary"
# "word 'rj2012' not in vocabulary"
# "word 'apacip' not in vocabulary"
# "word 'ipsystems' not in vocabulary"
# "word 'retps' not in vocabulary"
# "word 'b19' not in vocabulary"
# "word '985' not in vocabulary"
# "word '00206' not in vocabulary"
# "word '80200' not in vocabulary"
# "word '318' not in vocabulary"
# "word '758' not in vocabulary"
# "word '2649' not in vocabulary"
# "word 'uf´s' not in vocabulary"
# "word '204' not in vocabulary"
# "word '157' not in vocabulary"
# "word '809' not in vocabulary"
# "word '0017' not in vocabulary"
# "word '178' not in vocabulary"
# "word '23464' not in vocabulary"
# "word '193' not in vocabulary"
# "word '“reserva' not in vocabulary"
# "word 'realizacao' not in vocabulary"
# "word 'cidic' not in vocabulary"
# "word '998' not in vocabulary"
# "word '820' not in vocabulary"
# "word '03100200670201589' not in vocabulary"
# "word '3400' not in vocabulary"
# "word '189' not in vocabulary"
# "word '23118' not in vocabulary"
# "word '097' not in vocabulary"
# "word 'e'' not in vocabulary"
# "word '408' not in vocabulary"
# "word '537' not in vocabulary"
# "word '907' not in vocabulary"
# "word 'cracha' not in vocabulary"
# "word '87093111' not in vocabulary"
# "word '53168' not in vocabulary"
# "word '003360' not in vocabulary"
# "word '822' not in vocabulary"
# "word 'contabeis' not in vocabulary"
# "word '079' not in vocabulary"
# "word '780' not in vocabulary"
# "word '6°' not in vocabulary"
# "word '336' not in vocabulary"
# "word '283' not in vocabulary"
# "word '751' not in vocabulary"
# "word '816' not in vocabulary"
# "word 'saips' not in vocabulary"
# "word '943' not in vocabulary"
# "word '256' not in vocabulary"
# "word '062' not in vocabulary"
# "word 'cnpj's' not in vocabulary"
# "word '181' not in vocabulary"
# "word '6764' not in vocabulary"
# "word 'cliamb' not in vocabulary"
# "word '511' not in vocabulary"
# "word '058' not in vocabulary"
# "word '994' not in vocabulary"
# "word '000245' not in vocabulary"
# "word 'm70' not in vocabulary"
# "word '1913' not in vocabulary"
# "word 'potreirito' not in vocabulary"
# "word '126' not in vocabulary"
# "word '099' not in vocabulary"
# "word 'portalsinan' not in vocabulary"
# "word '5101' not in vocabulary"
# "word '083' not in vocabulary"
# "word '2124' not in vocabulary"
# "word '281' not in vocabulary"
# "word 'igov2014' not in vocabulary"
# "word '8645' not in vocabulary"
# "word '1524' not in vocabulary"
# "word 'cadsenha' not in vocabulary"
# "word 'fnhis' not in vocabulary"
# "word 'ctdf' not in vocabulary"
# "word '48516' not in vocabulary"
# "word '000786' not in vocabulary"
# "word '665' not in vocabulary"
# "word 'àquele' not in vocabulary"
# "word '368' not in vocabulary"
# "word '757' not in vocabulary"
# "word '223' not in vocabulary"
# "word '898' not in vocabulary"
# "word '864' not in vocabulary"
# "word 'if's' not in vocabulary"
# "word '305' not in vocabulary"
# "word 'tatyene' not in vocabulary"
# "word '934' not in vocabulary"
# "word '628' not in vocabulary"
# "word '046' not in vocabulary"
# "word 'qrstae' not in vocabulary"
# "word '8078' not in vocabulary"
# "word '249' not in vocabulary"
# "word '846' not in vocabulary"
# "word '420' not in vocabulary"
# "word '1000' not in vocabulary"
# "word '424' not in vocabulary"
# "word '1718' not in vocabulary"
# "word 'schveiger' not in vocabulary"
# "word '472' not in vocabulary"
# "word '696' not in vocabulary"
# "word '651' not in vocabulary"
# "word '773' not in vocabulary"
# "word '454' not in vocabulary"
# "word 'dataescolabrasil' not in vocabulary"
# "word '795' not in vocabulary"
# "word 'srprf' not in vocabulary"
# "word 'nº2' not in vocabulary"
# "word 'cggp' not in vocabulary"
# "word '31º' not in vocabulary"
# "word '441' not in vocabulary"
# "word 'cgnor' not in vocabulary"
# "word '857' not in vocabulary"
# "word 'prodin' not in vocabulary"
# "word '684' not in vocabulary"
# "word '04500' not in vocabulary"
# "word 'hmgv' not in vocabulary"
# "word 'dii's' not in vocabulary"
# "word '6h' not in vocabulary"
# "word 'capesesp' not in vocabulary"
# "word '“minha' not in vocabulary"
# "word '24h' not in vocabulary"
# "word '501132' not in vocabulary"
# "word '504' not in vocabulary"
# "word '325' not in vocabulary"
# "word '727' not in vocabulary"
# "word '372' not in vocabulary"
# "word 'emissao' not in vocabulary"
# "word 'indenizacao' not in vocabulary"
# "word '8745' not in vocabulary"
# "word '678' not in vocabulary"
# "word '0100' not in vocabulary"
# "word '251' not in vocabulary"
# "word '21417414' not in vocabulary"
# "word 'jcdf' not in vocabulary"
# "word '515' not in vocabulary"
# "word '085' not in vocabulary"
# "word '“departamento”' not in vocabulary"
# "word 'siorg' not in vocabulary"
# "word '3016' not in vocabulary"
# "word 'dirad' not in vocabulary"
# "word '906' not in vocabulary"
# "word '206' not in vocabulary"
# "word '219' not in vocabulary"
# "word '235' not in vocabulary"
# "word '284' not in vocabulary"
# "word '352' not in vocabulary"
# "word '756' not in vocabulary"
# "word 'coobahia' not in vocabulary"
# "word '658' not in vocabulary"
# "word '370' not in vocabulary"
# "word '0008' not in vocabulary"
# "word '10951' not in vocabulary"
# "word 'mg004' not in vocabulary"
# "word '797' not in vocabulary"
# "word '173' not in vocabulary"
# "word 'm2' not in vocabulary"
# "word '4°' not in vocabulary"
# "word '48610' not in vocabulary"
# "word 'plataformacarolinabori' not in vocabulary"
# "word ''dm' not in vocabulary"
# "word '765' not in vocabulary"
# "word '507' not in vocabulary"
# "word 'gsistes' not in vocabulary"
# "word '854' not in vocabulary"
# "word '664' not in vocabulary"
# "word '560' not in vocabulary"
# "word 'cgesp' not in vocabulary"
# "word '662' not in vocabulary"
# "word 'a2' not in vocabulary"
# "word '633' not in vocabulary"
# "word 'odúlia' not in vocabulary"
# "word '638' not in vocabulary"
# "word 'jeunon' not in vocabulary"
# "word '10515777' not in vocabulary"
# "word '950' not in vocabulary"
# "word '769' not in vocabulary"
# "word '646' not in vocabulary"
# "word 'bvsms' not in vocabulary"
# "word '23079' not in vocabulary"
# "word 'colocacao' not in vocabulary"
# "word '615' not in vocabulary"
# "word '229' not in vocabulary"
# "word '363' not in vocabulary"
# "word '407' not in vocabulary"
# "word 'superior”' not in vocabulary"
# "word '7463' not in vocabulary"
# "word '1333' not in vocabulary"
# "word 'nawrocky' not in vocabulary"
# "word '484' not in vocabulary"
# "word '023' not in vocabulary"
# "word '644' not in vocabulary"
# "word 'srtm30' not in vocabulary"
# "word 'adalvio' not in vocabulary"
# "word 'governanca' not in vocabulary"
# "word 'governancapublica' not in vocabulary"
# "word 'coestado' not in vocabulary"
# "word 'aprovacao' not in vocabulary"
# "word '2a' not in vocabulary"
# "word '01580' not in vocabulary"
# "word '054' not in vocabulary"
# "word '004155' not in vocabulary"
# "word '50305' not in vocabulary"
# "word '8o' not in vocabulary"
# "word 'www1' not in vocabulary"
# "word 'supgp' not in vocabulary"
# "word '371' not in vocabulary"
# "word '426' not in vocabulary"
# "word '15h' not in vocabulary"
# "word 'fundahc' not in vocabulary"
# "word '584' not in vocabulary"
# "word 'cbvd' not in vocabulary"
# "word 'sicro' not in vocabulary"
# "word '386' not in vocabulary"
# "word '163' not in vocabulary"
# "word '3082' not in vocabulary"
# "word '952' not in vocabulary"
# "word '“todos' not in vocabulary"
# "word 'm19' not in vocabulary"
# "word '393' not in vocabulary"
# "word 'presados' not in vocabulary"
# "word 'restricao' not in vocabulary"
# "word '9057' not in vocabulary"
# "word 'macapa' not in vocabulary"
# "word '399' not in vocabulary"
# "word '8429' not in vocabulary"
# "word '“auditor”' not in vocabulary"
# "word '701037' not in vocabulary"
# "word '435' not in vocabulary"
# "word '920' not in vocabulary"
# "word 'cgspcd' not in vocabulary"
# "word 'cuty' not in vocabulary"
# "word '338' not in vocabulary"
# "word '737' not in vocabulary"
# "word '000117' not in vocabulary"
# "word '50000' not in vocabulary"
# "word '1958' not in vocabulary"
# "word '566' not in vocabulary"
# "word '1957' not in vocabulary"
# "word '5794' not in vocabulary"
# "word 'cppd' not in vocabulary"
# "word 'ibqn' not in vocabulary"
# "word 'd'alcantara' not in vocabulary"
# "word '583' not in vocabulary"
# "word '606' not in vocabulary"
# "word '1927' not in vocabulary"
# "word '088' not in vocabulary"
# "word 'nº01' not in vocabulary"
# "word '053' not in vocabulary"
# "word '0003' not in vocabulary"
# "word '081' not in vocabulary"
# "word '427' not in vocabulary"
# "word '0304354671768' not in vocabulary"
# "word '0304389821790' not in vocabulary"
# "word '1406' not in vocabulary"
# "word 'apolice' not in vocabulary"
# "word '045' not in vocabulary"
# "word '733' not in vocabulary"
# "word '8ª' not in vocabulary"
# "word '3412' not in vocabulary"
# "word 'sigecon' not in vocabulary"
# "word '912' not in vocabulary"
# "word 'subscretarias' not in vocabulary"
# "word '379' not in vocabulary"
# "word '20mg' not in vocabulary"
# "word '232' not in vocabulary"
# "word '0005' not in vocabulary"
# "word '629' not in vocabulary"
# "word '333' not in vocabulary"
# "word '16°' not in vocabulary"
# "word 'xianghe' not in vocabulary"
# "word 'kleinmond' not in vocabulary"
# "word '01200' not in vocabulary"
# "word 'fmce' not in vocabulary"
# "word '266' not in vocabulary"
# "word '919' not in vocabulary"
# "word '340' not in vocabulary"
# "word '483' not in vocabulary"
# "word 'ssan' not in vocabulary"
# "word 'fiscalizacao' not in vocabulary"
# "word 'ffa's' not in vocabulary"
# "word '“b”' not in vocabulary"
# "word '“c”' not in vocabulary"
# "word '558' not in vocabulary"
# "word 'fopag' not in vocabulary"
# "word '158267' not in vocabulary"
# "word '070' not in vocabulary"
# "word '355' not in vocabulary"
# "word 'a1' not in vocabulary"
# "word '183' not in vocabulary"
# "word 'srrf10' not in vocabulary"
# "word '367' not in vocabulary"
# "word 'cpgf' not in vocabulary"
# "word '3808' not in vocabulary"
# "word '221' not in vocabulary"
# "word '060' not in vocabulary"
# "word '1065' not in vocabulary"
# "word 'v1' not in vocabulary"
# "word 'v2' not in vocabulary"
# "word 'hctm' not in vocabulary"
# "word '“que' not in vocabulary"
# "word '611' not in vocabulary"
# "word '04941' not in vocabulary"
# "word '432' not in vocabulary"
# "word '1330' not in vocabulary"
# "word 'hnas' not in vocabulary"
# "word '974' not in vocabulary"
# "word '415' not in vocabulary"
# "word 'siass' not in vocabulary"
# "word '808' not in vocabulary"
# "word '410' not in vocabulary"
# "word '23034' not in vocabulary"
# "word '412' not in vocabulary"
# "word '490' not in vocabulary"
# "word '7311' not in vocabulary"
# "word 'licitacao' not in vocabulary"
# "word '40ch' not in vocabulary"
# "word '375' not in vocabulary"
# "word '1954' not in vocabulary"
# "word '1100' not in vocabulary"
# "word 'u00e3o' not in vocabulary"
# "word 'rvne' not in vocabulary"
# "word '000490' not in vocabulary"
# "word '485' not in vocabulary"
# "word '“parâmetros' not in vocabulary"
# "word 'infantil”' not in vocabulary"
# "word '779' not in vocabulary"
# "word '701' not in vocabulary"
# "word '683' not in vocabulary"
# "word 'revalidacao' not in vocabulary"
# "word 'teleserviço' not in vocabulary"
# "word '23100' not in vocabulary"
# "word 'unisant’anna' not in vocabulary"
# "word '“curso' not in vocabulary"
# "word '60502' not in vocabulary"
# "word 'empresometro' not in vocabulary"
# "word 'tecnologo' not in vocabulary"
# "word '026' not in vocabulary"
# "word '172' not in vocabulary"
# "word '\xa0' not in vocabulary"
# "word 'aquisicao' not in vocabulary"
# "word '983' not in vocabulary"
# "word '12855' not in vocabulary"
# "word '872' not in vocabulary"
# "word 'trabalho”' not in vocabulary"
# "word 'raiox' not in vocabulary"
# "word 'rohrs' not in vocabulary"
# "word '00015500' not in vocabulary"
# "word '1820' not in vocabulary"
# "word '0021' not in vocabulary"
# "word '834' not in vocabulary"
# "word 'rj2015' not in vocabulary"
# "word 'terceiradas' not in vocabulary"
# "word 'fomeri' not in vocabulary"
# "word 'drprf' not in vocabulary"
# "word 'o6' not in vocabulary"
# "word 'jj8063' not in vocabulary"
# "word '509' not in vocabulary"
# "word '289' not in vocabulary"
# "word 'skopinski' not in vocabulary"
# "word 'tenasa' not in vocabulary"
# "word '2936' not in vocabulary"
# "word 'mpdsv' not in vocabulary"
# "word 'pncrc' not in vocabulary"
# "word 'nutrisus' not in vocabulary"
# "word '1rm' not in vocabulary"
# "word '252' not in vocabulary"
# "word '99902000092201788' not in vocabulary"
# "word '\x0b' not in vocabulary"
# "word '5068' not in vocabulary"
# "word 'sisfiesportal' not in vocabulary"
# "word 'pr3' not in vocabulary"
# "word 'didep' not in vocabulary"
# "word '3316' not in vocabulary"
# "word 'snipc' not in vocabulary"
# "word '08000' not in vocabulary"
# "word 'supervida' not in vocabulary"
# "word '2534' not in vocabulary"
# "word '1003' not in vocabulary"
# "word 'estipulantes' not in vocabulary"
# "word '001330' not in vocabulary"
# "word '306' not in vocabulary"
# "word 'crivelii' not in vocabulary"
# "word 'outrens' not in vocabulary"
# "word '000109' not in vocabulary"
# "word 'dessistencias' not in vocabulary"
# "word '516' not in vocabulary"
# "word '“sim”' not in vocabulary"
# "word '942' not in vocabulary"
# "word '279' not in vocabulary"
# "word '\xadsic' not in vocabulary"
# "word '8308' not in vocabulary"
# "word '9606' not in vocabulary"
# "word '620' not in vocabulary"
# "word '481004' not in vocabulary"
# "word '476001' not in vocabulary"
# "word '482018' not in vocabulary"
# "word 'cgcob' not in vocabulary"
# "word 'digevat' not in vocabulary"
# "word '833' not in vocabulary"
# "word 'ggpes' not in vocabulary"
# "word '002250' not in vocabulary"
# "word '002260' not in vocabulary"
# "word '388' not in vocabulary"
# "word 'schiesari' not in vocabulary"
# "word 'editalícia' not in vocabulary"
# "word '05210004394201699' not in vocabulary"
# "word '1206' not in vocabulary"
# "word '1208' not in vocabulary"
# "word 'b1' not in vocabulary"
# "word 'z1' not in vocabulary"
# "word '630' not in vocabulary"
# "word '342' not in vocabulary"
# "word 'pacuária' not in vocabulary"
# "word 'sufer' not in vocabulary"
# "word 'mg12300125' not in vocabulary"
# "word '04965437683' not in vocabulary"
# "word '842' not in vocabulary"
# "word '712' not in vocabulary"
# "word '876' not in vocabulary"
# "word '064' not in vocabulary"
# "word '077' not in vocabulary"
# "word '006699' not in vocabulary"
# "word '2015\xad70' not in vocabulary"
# "word '22090049038' not in vocabulary"
# "word '979' not in vocabulary"
# "word '458' not in vocabulary"
# "word '577' not in vocabulary"
# "word '571' not in vocabulary"
# "word '572' not in vocabulary"
# "word '981' not in vocabulary"
# "word '73620000' not in vocabulary"
# "word '999' not in vocabulary"
# "word '624' not in vocabulary"
# "word '523' not in vocabulary"
# "word '9°' not in vocabulary"
# "word '87113767' not in vocabulary"
# "word 'alinia' not in vocabulary"
# "word 'informação”' not in vocabulary"
# "word 'treponêmico' not in vocabulary"
# "word 'uhe's' not in vocabulary"
# "word 'srrf01' not in vocabulary"
# "word '667' not in vocabulary"
# "word '3786' not in vocabulary"
# "word '457' not in vocabulary"
# "word '961' not in vocabulary"
# "word '3322' not in vocabulary"
# "word '003407' not in vocabulary"
# "word '1300' not in vocabulary"
# "word '2014'' not in vocabulary"
# "word 'ipahn' not in vocabulary"
# "word 'exceedamericas' not in vocabulary"
# "word '2050' not in vocabulary"
# "word '71000' not in vocabulary"
# "word 'c2' not in vocabulary"
# "word 'c97' not in vocabulary"
# "word '4005' not in vocabulary"
# "word 'dilog' not in vocabulary"
# "word '623' not in vocabulary"
# "word '955' not in vocabulary"
# "word '1882' not in vocabulary"
# "word 'ggtox' not in vocabulary"
# "word '001348' not in vocabulary"
# "word 'd’oeste' not in vocabulary"
# "word '001483' not in vocabulary"
# "word 'previdenciario' not in vocabulary"
# "word '491' not in vocabulary"
# "word '22°' not in vocabulary"
# "word '44'' not in vocabulary"
# "word '16'' not in vocabulary"
# "word '292' not in vocabulary"
# "word '0164' not in vocabulary"
# "word 'ondomotriz' not in vocabulary"
# "word 'co2' not in vocabulary"
# "word '508' not in vocabulary"
# "word 'sistn' not in vocabulary"
# "word 'finbra' not in vocabulary"
# "word 'siconfi' not in vocabulary"
# "word '3500' not in vocabulary"
# "word '315130800' not in vocabulary"
# "word 'edital”' not in vocabulary"
# "word '5352' not in vocabulary"
# "word '647' not in vocabulary"
# "word 'mcpse' not in vocabulary"
# "word '382' not in vocabulary"
# "word '40km' not in vocabulary"
# "word 'interm' not in vocabulary"
# "word '6a' not in vocabulary"
# "word '000935' not in vocabulary"
# "word '2211' not in vocabulary"
# "word '17h' not in vocabulary"
# "word '08016007681201645' not in vocabulary"
# "word 'b94' not in vocabulary"
# "word '8066' not in vocabulary"
# "word '99928000208201791' not in vocabulary"
# "word 'weizur' not in vocabulary"
# "word 'cgcer' not in vocabulary"
# "word 'dcebas' not in vocabulary"
# "word '1020' not in vocabulary"
# "word 'amararo' not in vocabulary"
# "word '1920' not in vocabulary"
# "word 'gergep' not in vocabulary"
# "word '23106' not in vocabulary"
# "word 'lqf' not in vocabulary"
# "word '1473' not in vocabulary"
# "word '701437' not in vocabulary"
# "word 'pavimentacao' not in vocabulary"
# "word 'saneante' not in vocabulary"
# "word '307' not in vocabulary"
# "word 'diarq' not in vocabulary"
# "word '643' not in vocabulary"
# "word '681' not in vocabulary"
# "word '000897' not in vocabulary"
# "word 'elxe1' not in vocabulary"
# "word '265' not in vocabulary"
# "word 'srrf04' not in vocabulary"
# "word '1070' not in vocabulary"
# "word 'srrf06' not in vocabulary"
# "word 'srrf02' not in vocabulary"
# "word '374' not in vocabulary"
# "word '000155' not in vocabulary"
# "word 'conasp' not in vocabulary"
# "word 'plsv' not in vocabulary"
# "word '713' not in vocabulary"
# "word '00058' not in vocabulary"
# "word '48580' not in vocabulary"
# "word '000789' not in vocabulary"
# "word '03000000666201621' not in vocabulary"
# "word '4244' not in vocabulary"
# "word '000620' not in vocabulary"
# "word 'parua' not in vocabulary"
# "word '7071' not in vocabulary"
# "word '0107' not in vocabulary"
# "word '0362' not in vocabulary"
# "word '200mil' not in vocabulary"
# "word '704506365944716' not in vocabulary"
# "word '654' not in vocabulary"
# "word '101806' not in vocabulary"
# "word '910' not in vocabulary"
# "word '634' not in vocabulary"
# "word 'antiumectante' not in vocabulary"
# "word '9982' not in vocabulary"
# "word '37224' not in vocabulary"
# "word '03000200749201538' not in vocabulary"
# "word 'sinomaruft' not in vocabulary"
# "word '984091919' not in vocabulary"
# "word 'bndus' not in vocabulary"
# "word 'implantacao' not in vocabulary"
# "word '622' not in vocabulary"
# "word '692' not in vocabulary"
# "word '811' not in vocabulary"
# "word '000205' not in vocabulary"
# "word '095' not in vocabulary"
# "word 'sinat' not in vocabulary"
# "word '892' not in vocabulary"
# "word '768' not in vocabulary"
# "word '089' not in vocabulary"
# ...
# "word '000427' not in vocabulary"
# "word 'semiestruturada' not in vocabulary"
# "word 'quallity' not in vocabulary"
# "word '0670068' not in vocabulary"
# "word '6100' not in vocabulary"
# "word '031849' not in vocabulary"
# "word 'tvcomunitaria' not in vocabulary"
# "word 'n°1590' not in vocabulary"
# "word '002885' not in vocabulary"
# "word 'cartografico' not in vocabulary"
# "word 'inhamã' not in vocabulary"
# "word 'alexbbarros' not in vocabulary"
# "word '366075' not in vocabulary"
# "word 'tarjamento' not in vocabulary"
# "word 'funciona4r' not in vocabulary"
# "word 'parambú' not in vocabulary"
# "word 'reduc¸a' not in vocabulary"
# "word 'compensac¸o' not in vocabulary"
# "word 'me´dio' not in vocabulary"
# "word 'restituic¸o' not in vocabulary"
# "word '8h' not in vocabulary"
# "word 'sessp' not in vocabulary"
# "word '706204087088369' not in vocabulary"
# "word '998390771' not in vocabulary"
# "word 'juacema' not in vocabulary"
# "word 'ba00120' not in vocabulary"
# "word 'ba00121' not in vocabulary"
# "word 'ba00645' not in vocabulary"
# "word 'inidicios' not in vocabulary"
# "word '08666' not in vocabulary"
# "word '23480006225201695' not in vocabulary"
# "word 'rubenspa' not in vocabulary"
# "word '98217' not in vocabulary"
# "word '6607' not in vocabulary"
# "word 'evida' not in vocabulary"
# "word '03626' not in vocabulary"
# "word '000467' not in vocabulary"
# "word 'região”' not in vocabulary"
# "word 'gexsal' not in vocabulary"
# "word 'sódigo' not in vocabulary"
# "word '12990' not in vocabulary"
# "word '61a' not in vocabulary"
# "word 'dgits' not in vocabulary"
# "word 'seprov' not in vocabulary"
# "word '752' not in vocabulary"
# "word '0013' not in vocabulary"
# "word '5187' not in vocabulary"
# "word 'cipeiros' not in vocabulary"
# "word 'comodidate' not in vocabulary"
# "word '082538' not in vocabulary"
# "word '0321537' not in vocabulary"
# "word 'l12527' not in vocabulary"
# "word 'd7724' not in vocabulary"
# "word '2°semestre' not in vocabulary"
# "word 'ordenatório' not in vocabulary"
# "word '205352' not in vocabulary"
# "word 'brimz' not in vocabulary"
# "word '23480012261201779' not in vocabulary"
# "word 'gratís' not in vocabulary"
# "word 'fafram' not in vocabulary"
# "word 'daig' not in vocabulary"
# "word 'pesmanente' not in vocabulary"
# "word 'orgõa' not in vocabulary"
# "word 'pesmanência' not in vocabulary"
# "word 'goiran' not in vocabulary"
# "word '‘políticas' not in vocabulary"
# "word 'tecnológico’' not in vocabulary"
# "word 'cibio' not in vocabulary"
# "word '55338' not in vocabulary"
# "word '701958' not in vocabulary"
# "word 'seropedica' not in vocabulary"
# "word '34977' not in vocabulary"
# "word '3314' not in vocabulary"
# "word '8433' not in vocabulary"
# "word '8713' not in vocabulary"
# "word 'd011757985' not in vocabulary"
# "word 'procotolo' not in vocabulary"
# "word 'd011757985wd0000014855' not in vocabulary"
# "word 'pyc' not in vocabulary"
# "word '2623' not in vocabulary"
# "word '01093173472' not in vocabulary"
# "word '01760314949' not in vocabulary"
# "word 'danielcalegari' not in vocabulary"
# "word '99103' not in vocabulary"
# "word '6827' not in vocabulary"
# "word '23051' not in vocabulary"
# "word '001107' not in vocabulary"
# "word 'gilic' not in vocabulary"
# "word 'coaif' not in vocabulary"
# "word 'ggavv' not in vocabulary"
# "word 'sefic' not in vocabulary"
# "word '1010343' not in vocabulary"
# "word 'caarlos' not in vocabulary"
# "word 'òleo' not in vocabulary"
# "word '000827' not in vocabulary"
# "word '08389' not in vocabulary"
# "word '014551' not in vocabulary"
# "word 'irpf2016' not in vocabulary"
# "word '21052' not in vocabulary"
# "word '000766' not in vocabulary"
# "word '679159' not in vocabulary"
# "word 'codibge' not in vocabulary"
# "word 'codmunic' not in vocabulary"
# "word 'codmunic12' not in vocabulary"
# "word 'orgacad' not in vocabulary"
# "word 'dep5' not in vocabulary"
# "word 'prevest' not in vocabulary"
# "word 'agostiano' not in vocabulary"
# "word 'alub' not in vocabulary"
# "word 'sabeber' not in vocabulary"
# "word '4600203254' not in vocabulary"
# "word 'cadastal' not in vocabulary"
# "word 'ipueras' not in vocabulary"
# "word 'antemao' not in vocabulary"
# "word 'curosurf' not in vocabulary"
# "word 'chiesi' not in vocabulary"
# "word 'survanta' not in vocabulary"
# "word '46800000994201615' not in vocabulary"
# "word 'cdin' not in vocabulary"
# "word '“censo' not in vocabulary"
# "word '“exame' not in vocabulary"
# "word 'cooperaliança' not in vocabulary"
# "word 'efljc' not in vocabulary"
# "word 'eflul' not in vocabulary"
# "word 'forcel' not in vocabulary"
# "word 'hidropan' not in vocabulary"
# "word 'ienergia' not in vocabulary"
# "word 'jcupim' not in vocabulary"
# "word '03000001615201706' not in vocabulary"
# "word '48700006364201527' not in vocabulary"
# "word '“ocupantes' not in vocabulary"
# "word 'especial”' not in vocabulary"
# "word 'vasgas' not in vocabulary"
# "word 'cchnst' not in vocabulary"
# "word 'feredal' not in vocabulary"
# "word 'df000051' not in vocabulary"
# "word 'mr007240' not in vocabulary"
# "word '46206' not in vocabulary"
# "word '002445' not in vocabulary"
# "word '201694' not in vocabulary"
# "word 'sindiserviços' not in vocabulary"
# "word '925942' not in vocabulary"
# "word 'cpptae' not in vocabulary"
# "word '499' not in vocabulary"
# "word 'subsididar' not in vocabulary"
# "word 'rolmar' not in vocabulary"
# "word 'v0300' not in vocabulary"
# "word '561' not in vocabulary"
# "word '1b' not in vocabulary"
# "word 'institituição' not in vocabulary"
# "word '004184' not in vocabulary"
# "word 'n'' not in vocabulary"
# "word '003643' not in vocabulary"
# "word 'ppggosp' not in vocabulary"
# "word '“cervejeiro”' not in vocabulary"
# "word '8418' not in vocabulary"
# "word '48546008763201600' not in vocabulary"
# "word 'que\xa0contém' not in vocabulary"
# "word 'expedida\xa0pela' not in vocabulary"
# "word 'pronunciamento\xa0e' not in vocabulary"
# "word 'competente\xa0quanto' not in vocabulary"
# "word '2017\xa0que' not in vocabulary"
# "word 'andamento\xa0atual' not in vocabulary"
# "word 'do\xa0processo' not in vocabulary"
# "word 'da\xa0manifestação' not in vocabulary"
# "word 'sobre\xa0o' not in vocabulary"
# "word 'atual\xa0andamento\xa0do' not in vocabulary"
# "word 'em\xa0questão' not in vocabulary"
# "word 'desarquivarmos' not in vocabulary"
# "word 'digitalizarmos' not in vocabulary"
# "word 'pfufla' not in vocabulary"
# "word 'abonono' not in vocabulary"
# "word '001014' not in vocabulary"
# "word '5062' not in vocabulary"
# "word '020316' not in vocabulary"
# "word '233mb' not in vocabulary"
# "word '10mb' not in vocabulary"
# "word '0bxnhqdhc43e8b3hyzuf5z2xbdk0' not in vocabulary"
# "word '7842' not in vocabulary"
# "word 'bancen' not in vocabulary"
# "word '27468376' not in vocabulary"
# "word '10°' not in vocabulary"
# "word '168555168' not in vocabulary"
# "word '052480628' not in vocabulary"
# "word 'cmpj' not in vocabulary"
# "word 'iformada' not in vocabulary"
# "word 'indivivual' not in vocabulary"
# "word 'atgenciosamente' not in vocabulary"
# "word 'areasembargadas' not in vocabulary"
# "word 'consultapublicaareasembargadas' not in vocabulary"
# "word 'com1dn' not in vocabulary"
# "word '04923' not in vocabulary"
# "word '4929' not in vocabulary"
# "word '99945000016201695' not in vocabulary"
# "word '23000' not in vocabulary"
# "word '013562' not in vocabulary"
# "word 'reencaminhei' not in vocabulary"
# "word '“vale' not in vocabulary"
# "word 'talhada”' not in vocabulary"
# "word '701226' not in vocabulary"
# "word 'embasaria' not in vocabulary"
# "word 'revista30' not in vocabulary"
# "word 'curioníopolis' not in vocabulary"
# "word 'seadrill' not in vocabulary"
# "word '46093' not in vocabulary"
# "word 'razaosocial' not in vocabulary"
# "word 'idlinha' not in vocabulary"
# "word 'idsecao' not in vocabulary"
# "word 'tipodeservicoprincipal' not in vocabulary"
# "word 'abrati' not in vocabulary"
# "word '70070' not in vocabulary"
# "word 'efermagem' not in vocabulary"
# "word 'obrogado' not in vocabulary"
# "word '033409' not in vocabulary"
# "word '2016ne800240' not in vocabulary"
# "word '2016ob801164' not in vocabulary"
# "word '4638' not in vocabulary"
# "word 'responsam' not in vocabulary"
# "word 'possibilidde' not in vocabulary"
# "word 'm0305' not in vocabulary"
# "word '09º32'15' not in vocabulary"
# "word 'm0306' not in vocabulary"
# "word '09º31'34' not in vocabulary"
# "word 'm0307' not in vocabulary"
# "word '09º31'31' not in vocabulary"
# "word '60º56'14' not in vocabulary"
# "word 'm0308' not in vocabulary"
# "word '09º32'7' not in vocabulary"
# "word '60º56'40' not in vocabulary"
# "word '2031' not in vocabulary"
# "word 'pedifos' not in vocabulary"
# "word 'senhoes' not in vocabulary"
# "word '1831' not in vocabulary"
# "word 'defs' not in vocabulary"
# "word 'cnvs' not in vocabulary"
# "word 'unisef' not in vocabulary"
# "word 'pnlem' not in vocabulary"
# "word 'nº18' not in vocabulary"
# "word 'consideracao' not in vocabulary"
# "word 'ficarao' not in vocabulary"
# "word '1761' not in vocabulary"
# "word '3614' not in vocabulary"
# "word '2186' not in vocabulary"
# "word '1141' not in vocabulary"
# "word '1760' not in vocabulary"
# "word ''rol' not in vocabulary"
# "word 'desclassificadas'' not in vocabulary"
# "word 'pass379' not in vocabulary"
# "word '197912' not in vocabulary"
# "word '25002' not in vocabulary"
# "word '004179' not in vocabulary"
# "word 'gdpst' not in vocabulary"
# "word '2105682' not in vocabulary"
# "word '1176' not in vocabulary"
# "word 'cpsa”' not in vocabulary"
# "word '95106' not in vocabulary"
# "word '8769' not in vocabulary"
# "word '039427' not in vocabulary"
# "word '040192' not in vocabulary"
# "word '247148' not in vocabulary"
# "word '54800' not in vocabulary"
# "word '000798' not in vocabulary"
# "word '36267640' not in vocabulary"
# "word 'idek' not in vocabulary"
# "word '986320688' not in vocabulary"
# "word '0064374' not in vocabulary"
# "word 'circ379' not in vocabulary"
# "word 'www12' not in vocabulary"
# "word 'ecidadania' not in vocabulary"
# "word 'pesquisamateria' not in vocabulary"
# "word 'avastsafezone' not in vocabulary"
# "word '25620' not in vocabulary"
# "word '003830' not in vocabulary"
# "word '4138' not in vocabulary"
# "word '1027' not in vocabulary"
# "word '616250' not in vocabulary"
# "word 'codomar' not in vocabulary"
# "word '0547' not in vocabulary"
# "word 'recomendacoes' not in vocabulary"
# "word 'pddc' not in vocabulary"
# "word '2010001' not in vocabulary"
# "word 'ppgde' not in vocabulary"
# "word 'ancac' not in vocabulary"
# "word 'vancâncias' not in vocabulary"
# "word '001997' not in vocabulary"
# "word 'blasbalg' not in vocabulary"
# "word '1603' not in vocabulary"
# "word '°420675845' not in vocabulary"
# "word '663849' not in vocabulary"
# "word '3370' not in vocabulary"
# "word '4600386288' not in vocabulary"
# "word 'desarrazoável' not in vocabulary"
# "word '158122' not in vocabulary"
# "word '23208' not in vocabulary"
# "word '00897' not in vocabulary"
# "word 'enetendimento' not in vocabulary"
# "word 'mexsc's' not in vocabulary"
# "word 'endomediação' not in vocabulary"
# "word '§1o' not in vocabulary"
# "word 'maiele' not in vocabulary"
# "word 'disponibiizado' not in vocabulary"
# "word '2761' not in vocabulary"
# "word '005838' not in vocabulary"
# "word '1012639' not in vocabulary"
# "word '2014ne634373' not in vocabulary"
# "word '8829' not in vocabulary"
# "word 'corrupçaõ' not in vocabulary"
# "word 'decpcionado' not in vocabulary"
# "word 'rrealizada' not in vocabulary"
# "word 'dmco' not in vocabulary"
# "word 'gmgc' not in vocabulary"
# "word 'ctir' not in vocabulary"
# "word '12419660708' not in vocabulary"
# "word 'sj2' not in vocabulary"
# "word 'contratais' not in vocabulary"
# "word '079847' not in vocabulary"
# "word 'computacao' not in vocabulary"
# "word '000797' not in vocabulary"
# "word '277pr' not in vocabulary"
# "word 'km234' not in vocabulary"
# "word '03100000472201436' not in vocabulary"
# "word '25665' not in vocabulary"
# "word 'parelelos' not in vocabulary"
# "word 'manutenç' not in vocabulary"
# "word 'cepf' not in vocabulary"
# "word '908' not in vocabulary"
# "word 'pelizer' not in vocabulary"
# "word 'duplasena' not in vocabulary"
# "word 'infomassem' not in vocabulary"
# "word '2531' not in vocabulary"
# "word 'volitaria' not in vocabulary"
# "word '4600316288' not in vocabulary"
# "word '85ª' not in vocabulary"
# "word '86ª' not in vocabulary"
# "word '012365' not in vocabulary"
# "word 'sintrecesp' not in vocabulary"
# "word '486' not in vocabulary"
# "word '23480003323201671' not in vocabulary"
# "word '03100000572201713' not in vocabulary"
# "word 'depro' not in vocabulary"
# "word 'aponho' not in vocabulary"
# "word 'txgrac' not in vocabulary"
# "word 'txfqac' not in vocabulary"
# "word 'nmofupr' not in vocabulary"
# "word 'nmofute' not in vocabulary"
# "word 'nacter' not in vocabulary"
# "word 'nmoter' not in vocabulary"
# "word '04972204850' not in vocabulary"
# "word '48700002193201729' not in vocabulary"
# "word '896' not in vocabulary"
# "word 'sejur' not in vocabulary"
# "word 'orgáos' not in vocabulary"
# "word '004899' not in vocabulary"
# "word 'docepan' not in vocabulary"
# "word 'l1' not in vocabulary"
# "word 'l3' not in vocabulary"
# "word 'l4' not in vocabulary"
# "word '85086410' not in vocabulary"
# "word '024131' not in vocabulary"
# "word '819098' not in vocabulary"
# "word '466957' not in vocabulary"
# "word 'grupomekal' not in vocabulary"
# "word 'filemanager' not in vocabulary"
# "word '1340388819' not in vocabulary"
# "word 'previdenciarios' not in vocabulary"
# "word '01250' not in vocabulary"
# "word '022738' not in vocabulary"
# "word '00009661' not in vocabulary"
# "word '017810' not in vocabulary"
# "word 'iluminaçao' not in vocabulary"
# "word 'capacitacao' not in vocabulary"
# "word 'gedep' not in vocabulary"
# "word 'adional' not in vocabulary"
# "word '3281' not in vocabulary"
# "word '2109' not in vocabulary"
# "word '50606002206' not in vocabulary"
# "word '9823' not in vocabulary"
# "word '99101' not in vocabulary"
# "word '38025' not in vocabulary"
# "word 'logíst' not in vocabulary"
# "word 'geren' not in vocabulary"
# "word 'bossardi' not in vocabulary"
# "word '1923800998058989' not in vocabulary"
# "word '423' not in vocabulary"
# "word 'nº24' not in vocabulary"
# "word '28043014' not in vocabulary"
# "word '59626480' not in vocabulary"
# "word '98748' not in vocabulary"
# "word '3892' not in vocabulary"
# "word '364bmg0350' not in vocabulary"
# "word 'guarinhatã' not in vocabulary"
# "word '61993128857' not in vocabulary"
# "word '002880' not in vocabulary"
# "word 'òbito' not in vocabulary"
# "word '476' not in vocabulary"
# "word '10150' not in vocabulary"
# "word '81690150' not in vocabulary"
# "word 'icict' not in vocabulary"
# "word 'leniências' not in vocabulary"
# "word '12772' not in vocabulary"
# "word '13325' not in vocabulary"
# "word '06090121' not in vocabulary"
# "word '78091764715' not in vocabulary"
# "word 'etfc' not in vocabulary"
# "word 'francidca' not in vocabulary"
# "word '99100684' not in vocabulary"
# "word 'cespunb' not in vocabulary"
# "word '04962204640201564' not in vocabulary"
# "word '2357010133503' not in vocabulary"
# "word '4810' not in vocabulary"
# "word 'fg1' not in vocabulary"
# "word 'fg2' not in vocabulary"
# "word 'fg4' not in vocabulary"
# "word 'confeccoes' not in vocabulary"
# "word 'n576' not in vocabulary"
# "word '24112016' not in vocabulary"
# "word 'boletas' not in vocabulary"
# "word 'pagto' not in vocabulary"
# "word 'favot' not in vocabulary"
# "word '23088' not in vocabulary"
# "word '002864' not in vocabulary"
# "word '4600430342' not in vocabulary"
# "word '01448758000230' not in vocabulary"
# "word '003573' not in vocabulary"
# "word 'apulista' not in vocabulary"
# "word ''cidade'' not in vocabulary"
# "word '859' not in vocabulary"
# "word 'crediserv' not in vocabulary"
# "word 'cgmben' not in vocabulary"
# "word 'divcons' not in vocabulary"
# "word 'distratados' not in vocabulary"
# "word '48700002060201591' not in vocabulary"
# "word '48700002069201500' not in vocabulary"
# "word 'cobrançã' not in vocabulary"
# "word '4600526076' not in vocabulary"
# "word '4600526077' not in vocabulary"
# "word '4600526078' not in vocabulary"
# "word '0101640' not in vocabulary"
# "word 'edivilson' not in vocabulary"
# "word '99727429' not in vocabulary"
# "word '027394' not in vocabulary"
# "word '99715803' not in vocabulary"
# "word '2646' not in vocabulary"
# "word '14872' not in vocabulary"
# "word '2511' not in vocabulary"
# "word '33464' not in vocabulary"
# "word '23480000223201692' not in vocabulary"
# "word 'procristinação' not in vocabulary"

# %%
# Define model
def train_model(input_train, input_test, label_train, label_test,
                lstm_size=128, dropout=0.2, rec_dropout=0.2, lr=0.005, epochs=50, att_heads=4, max_length=128, 
                vocab_size=None, embed_size=None, emb_trainable=False, batch=128, early_stopping=5,
                save_dir="D:/resultados/checkpoins_solicitacao_keras_mh_att/", best_predefined_f1=0.390):

    # Time now
    now = datetime.now().strftime("%Y%m%d_%H%M%S")
    
    # Log
    log_dir = save_dir + now
    
    # Model Saver    
    if not os.path.exists(log_dir):
        os.makedirs(log_dir)
    
    log_file = open(os.path.join(log_dir,"log.txt"), mode="a")
    
    # Save Params
    params = {
        'lstm_size': lstm_size,
        'dropout': dropout,
        'rec_dropout': rec_dropout,
        'lr': lr,
        'epochs': epochs,
        'att_heads': att_heads,
        'max_length': max_length,
        'vocab_size': vocab_size,
        'embed_size': embed_size,
        'emb_trainable': emb_trainable,
        'batch': batch,
        'early_stopping': early_stopping,
        'log_dir': log_dir,
        'best_predefined_f1': best_predefined_f1}
    
    # Saving Parameters
    with open(os.path.join(log_dir, 'params.txt'),'a') as f:
        f.write('\n\n' + ('#'*60))
        f.write('\nParameters:\n')
        f.write('now: ' + str(now))
        f.write('\n' + dumps(params) + '\n')
    
    # input
    inp = Input(shape=(max_length, ))

    # Embedding layer - https://keras.io/layers/embeddings/
    embedding_layer = Embedding(vocab_size,
                                embed_size,                                
                                weights=[embedding_matrix],
                                input_length=max_length,
                                trainable=emb_trainable,
                                name='Embedding')(inp)

    # Bidirectional Layer
    bilstm_layer = Bidirectional(LSTM(
                        units=lstm_size,
                        return_sequences=True,
                        dropout=dropout,
                        recurrent_dropout=rec_dropout,
                        name='LSTM'))(embedding_layer)    

    # MultiHead-Attention Layer
    #https://pypi.org/project/keras-multi-head/
    multiHead_att_layer = MultiHeadAttention(head_num=att_heads, name='Multi-Head-Attention')(bilstm_layer)

    dropout_intermed_layer = Dropout(0.5)(multiHead_att_layer)

    # # Flatten
    flatten_layer = Flatten(name='Flatten')(dropout_intermed_layer)

    dense_intermed_layer = Dense(128, activation='relu')(flatten_layer)
    dropout_intermed_2_layer = Dropout(dropout)(dense_intermed_layer)

    # # # # Dense Layer
    if binary:
        dense_layer = Dense(1, activation='sigmoid')(dropout_intermed_2_layer)    
    else:
        dense_layer = Dense(num_labels, activation='softmax')(dropout_intermed_2_layer)    
    
    model = Model(inputs=inp, outputs=dense_layer)
    # model.summary()
    
    # Compile
    model.compile(optimizer=Adam(lr=lr), loss='binary_crossentropy', metrics=['accuracy', precision_m, recall_m, f1_m])
    
    # callbacks
    es_callback = EarlyStopping(monitor='val_loss', patience=early_stopping, verbose=1, mode='min')
    
    # Fitting Model
    model.fit(input_train,
              label_train,
              epochs=epochs,
              batch_size=batch,
              validation_data=(input_test, label_test),
              verbose=0,
              callbacks=[es_callback])
    
    # PLOT LOSS
    plt.title('Loss')
    plt.plot(model.history.history['loss'], label='train')
    plt.plot(model.history.history['val_loss'], label='test')
    plt.legend()
    #plt.show();
    plt.savefig(os.path.join(log_dir,'Loss.png'))
    plt.close()
    
    # Classification
    y_pred = model.predict(input_test, batch_size=batch, verbose=1)
    y_pred_bool = np.argmax(y_pred, axis=1)
    
    if not binary:
        label_test = np.argmax(label_test.values, axis=1)
    
    # Metrics
    f1 = f1_score(label_test, y_pred_bool, average='weighted')
    print(f"Best Test F1-Score: {f1:.3f}")
    
    print("#"*60 + '\n', file=log_file)
    print(classification_report(label_test, y_pred_bool), file=log_file)
    print("#"*60+ '\n', file=log_file)
    
    # Flush log file
    log_file.flush()
    log_file.close()
    
    # Save final result
    with open(os.path.join(log_dir[:-16], 'output.txt'),'a') as f:
        f.write('\n\n')
        f.write(log_dir)
        f.write('\n')
        f.write(f"Best Test F1-Score: {f1:.3f}")
        
    # save model and architecture to single file
    if f1 > best_predefined_f1:
        model.save(os.path.join(log_dir, "model.h5"))
        print("Saved model to disk")

# %%
# Model Params
lstm_size_list = [256, 512]
dropout_list = [0.25, 0.5]
rec_dropout_list = [0.1, 0.25, 0.5]
lr_list = [1e-3, 5e-4, 1e-4, 5e-5, 5e-6]

all_params = [lstm_size_list] + [dropout_list] + [rec_dropout_list] + [lr_list]

for each in itertools.product(*all_params):    
    lstm_size, dropout, rec_dropout, lr = each
    
    # Params
    print('lstm_size: ' + str(lstm_size))
    print('\tdropout: ' + str(dropout))
    print('\trec_dropout: ' + str(rec_dropout))
    print('\tlr: ' + str(lr))
    
    # train
    train_model(input_train, input_test, label_train, label_test, lstm_size, dropout, rec_dropout, lr, epochs=50,
                att_heads=4, max_length=max_length, vocab_size=vocab_size, embed_size=embed_size, emb_trainable=False, batch=128,
                early_stopping=5, save_dir="D:/Outputs_Mestrado/resultados_Atendimento/checkpoins_solicitacao_keras_mh_att/",
                best_predefined_f1=0.424)
# Out:
# lstm_size: 256
# 	dropout: 0.25
# 	rec_dropout: 0.1
# 	lr: 0.001
# Epoch 00011: early stopping
# 2993/2993 [==============================] - 3s 862us/step
# Best Test F1-Score: 0.405
# lstm_size: 256
# 	dropout: 0.25
# 	rec_dropout: 0.1
# 	lr: 0.0005
# Epoch 00012: early stopping
# 2993/2993 [==============================] - 3s 908us/step
# Best Test F1-Score: 0.401
# lstm_size: 256
# 	dropout: 0.25
# 	rec_dropout: 0.1
# 	lr: 0.0001
# Epoch 00012: early stopping
# 2993/2993 [==============================] - 3s 870us/step
# Best Test F1-Score: 0.413
# lstm_size: 256
# 	dropout: 0.25
# 	rec_dropout: 0.1
# 	lr: 5e-05
# Epoch 00022: early stopping
# 2993/2993 [==============================] - 3s 852us/step
# Best Test F1-Score: 0.428
# Saved model to disk
# lstm_size: 256
# 	dropout: 0.25
# 	rec_dropout: 0.1
# 	lr: 5e-06
# Epoch 00050: early stopping
# 2993/2993 [==============================] - 4s 1ms/step
# Best Test F1-Score: 0.408
# lstm_size: 256
# 	dropout: 0.25
# 	rec_dropout: 0.25
# 	lr: 0.001
# Epoch 00011: early stopping
# 2993/2993 [==============================] - 3s 864us/step
# Best Test F1-Score: 0.411
# lstm_size: 256
# 	dropout: 0.25
# 	rec_dropout: 0.25
# 	lr: 0.0005
# Epoch 00013: early stopping
# 2993/2993 [==============================] - 3s 866us/step
# Best Test F1-Score: 0.424
# Saved model to disk
# lstm_size: 256
# 	dropout: 0.25
# 	rec_dropout: 0.25
# 	lr: 0.0001
# Epoch 00015: early stopping
# 2993/2993 [==============================] - 3s 874us/step
# Best Test F1-Score: 0.407
# lstm_size: 256
# 	dropout: 0.25
# 	rec_dropout: 0.25
# 	lr: 5e-05
# Epoch 00018: early stopping
# 2993/2993 [==============================] - 3s 863us/step
# Best Test F1-Score: 0.412
# lstm_size: 256
# 	dropout: 0.25
# 	rec_dropout: 0.25
# 	lr: 5e-06
