# %%
#!pip install tensorflow-gpu
# Downgrade 
#smart_open to 1.10.0 -> https://github.com/RaRe-Technologies/smart_open/issues/475
# python -m pip install -U smart_open==1.10.0

# %%
import os
# %load_ext tensorboard

# %%
###########################################
# How to make deterministic experiments?
###########################################

# Main Sources:
    # 1) https://github.com/NVIDIA/tensorflow-determinism
    # 2) https://pypi.org/project/tensorflow-determinism/#description
            # There are currently two main ways to access GPU-deterministic functionality in TensorFlow for most
            # deep learning applications. 
            # 2.1) The first way is to use an NVIDIA NGC TensorFlow container. - https://www.nvidia.com/en-us/gpu-cloud/containers/
            # 2.2. The second way is to use version 1.14, 1.15, or 2.0 of stock TensorFlow with GPU support, 
            #      plus the application of a patch supplied in this repo.

# # # Ensure Deterministic behaviour
import random
import numpy as np
import tensorflow as tf
os.environ['TF_DETERMINISTIC_OPS'] = '1'

# Now using tensorflow 2.1.0, so no need to patch
# from tfdeterminism import patch
#patch()

seed = 42
os.environ['PYTHONHASHSEED']=str(seed)
random.seed(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
############################################

# %%
# utils
from distutils.version import LooseVersion
from tqdm import tqdm_notebook
from datetime import datetime
from time import time

import warnings
import pickle
import gc
import sys
from json import dumps
import itertools
import re

# Data
import pandas as pd
import spacy

# Viz
import matplotlib.pyplot as plt

# Machine Learning
import tensorflow.keras.backend as K
from keras.preprocessing.text import one_hot, Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.layers import Input, Dropout, Bidirectional, LSTM, Flatten, Dense, Reshape
from keras.layers.embeddings import Embedding
from keras.models import Sequential, Model
from keras.optimizers import Adam
from keras.callbacks.callbacks import EarlyStopping
#from keras.callbacks import EarlyStopping, TensorBoard
#from tensorflow.keras.callbacks import EarlyStopping, TensorBoard
from keras_self_attention import SeqSelfAttention
from keras_multi_head import MultiHead, MultiHeadAttention

from sklearn.metrics import f1_score, classification_report
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# NLP Models
from gensim.models import Word2Vec, KeyedVectors
#w2v_models_path = 'C:/Users/arthu/Desktop/22032020 - Experimentos/05. Organizado/02. Notebooks/models/'
w2v_models_path = 'D:/Mestrado/Dissertação/07 .Dissertação Final/02. Experimentos/02. Word Embbedings/'
# Out:
# Using TensorFlow backend.

# %%
# METRICS
# def f1_score(y_true, y_pred):

#     # Count positive samples.
#     c1 = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
#     c2 = K.sum(K.round(K.clip(y_pred, 0, 1)))
#     c3 = K.sum(K.round(K.clip(y_true, 0, 1)))

# #     # If there are no true samples, fix the F1 score at 0.
# #     if c3 == 0:
# #         return 0

#     # How many selected items are relevant?
#     precision = c1 / c2

#     # How many relevant items are selected?
#     recall = c1 / c3

#     # Calculate f1_score
#     f1_score = 2 * (precision * recall) / (precision + recall)
#     return f1_score

# def recall(y_true, y_pred):

#     # Count positive samples.
#     c1 = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
#     c3 = K.sum(K.round(K.clip(y_true, 0, 1)))

# #     # If there are no true samples, fix the F1 score at 0.
# #     if c3 == 0:
# #         return 0

#     # How many relevant items are selected?
#     recall = c1 / c3
    
#     return recall


# def precision(y_true, y_pred):

#     # Count positive samples.
#     c1 = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
#     c2 = K.sum(K.round(K.clip(y_pred, 0, 1)))

#     # How many selected items are relevant?
#     precision = c1 / c2

#     return precision

# https://datascience.stackexchange.com/questions/45165/how-to-get-accuracy-f1-precision-and-recall-for-a-keras-model
def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %%
print('tf version: ' + tf.__version__)
# Out:
# tf version: 2.1.0-rc2

# %%
#Variables
current_exp = 'Atendimento-Balanced-Multiclass'
if 'Binary' in current_exp:
    binary = True
else:
    binary = False
    
base_path = 'C:/Users/arthu/Desktop/22032020 - Experimentos/05. Organizado/03. Datasets/' + current_exp
save_path = 'output'

sentence = 'resp-text'
label = 'Atendimento'

x_train_file = 'X_train.csv'
y_train_file = 'y_train.csv'
x_test_file = 'X_test.csv'
y_test_file = 'y_test.csv'

#Load data
X_train = pd.read_csv(os.path.join(base_path, x_train_file), sep=';', encoding='utf-8')
y_train = pd.read_csv(os.path.join(base_path, y_train_file), sep=';', encoding='utf-8')
X_test = pd.read_csv(os.path.join(base_path, x_test_file), sep=';', encoding='utf-8')
y_test = pd.read_csv(os.path.join(base_path, y_test_file), sep=';', encoding='utf-8')

#Checking on data
print(X_train.columns)
print(X_train.shape)
print(y_train[label].value_counts())
print(y_test[label].value_counts())
# Out:
# Index(['pid', 'req-text', 'resp-text', '1funct-request', '2pronoun-request',
#        '3ppron-request', '4i-request', '5we-request', '6you-request',
#        '7shehe-request',
#        ...
#        '58home-response', '59money-response', '60relig-response',
#        '61death-response', '62assent-response', '63nonfl-response',
#        '64filler-response', 'Clareza', 'Atendimento', 'tempo_resposta'],
#       dtype='object', length=134)
# (6982, 134)
# 0    2367
# 1    2319
# 2    2296
# Name: Atendimento, dtype: int64
# 2    1029
# 1    1006
# 0     958
# Name: Atendimento, dtype: int64

# %%
# Keep only text columns
X_train.drop(columns=X_train.columns[3:], inplace=True)
X_test.drop(columns=X_train.columns[3:], inplace=True)

# %%
###################################################
X_train['sentence'] = X_train[sentence]
X_test['sentence'] = X_test[sentence]

y_train['label'] = y_train[label]
y_test['label'] = y_test[label]

##################################################################
# CUT DATAFRAME
# factor = 10000
# df = pd.concat([df[df.label=='1'][0:factor], df[df.label=='0'][0:factor]])
##################################################################

# Report the number of sentences.
print('Number of training sentences: {:,}\n'.format(X_train.shape[0]))

# Report the classes balance.
print('Classes distribuition: \n')
print(y_train[label].value_counts())

# Display 10 random rows from the data.
X_train.sample(10)
# Out:
# Number of training sentences: 6,982
#
# Classes distribuition:
#
# 0    2367
# 1    2319
# 2    2296
# Name: Atendimento, dtype: int64
#          pid                                           req-text  \
# 4119  414762  Gostaria de receber todas as informações refer...
# 3477  423065  Prezados, boa tarde! Solicito a gentileza de i...
# 4322  432042  1. PEDIDOS DE ACESSO À INFORMAÇÃO 1.1. PEDIDO ...
# 3349  553831  Considerando o posicionamento formal da DIPAR ...
# 469   546829  Prezados senhores, solicito para fins acadêmic...
# 538   467278  NÚMEROS DE 2017 DE CARGOS VAGOS DE SERVIDORES ...
# 6636  347965  Gostaria de saber quando serão convocados os a...
# 5820  445187              O pedido se encontra no anexo abaixo.
# 1047  565317  1.\tA Instituição utiliza sistema de cotas? 1....
# 1219  327624  Estou esperando a nomeação pelo concurso reali...
#
#                                               resp-text  \
# 4119  Prezado a Cidadão ã , 1 . Conforme solicitação...
# 3477  Prezado Senhor , O processo mencionado nademan...
# 4322   Segue respostas deste Setor . RESPOSTA A PEDI...
# 3349  Prezado Senhor Carlos , Permanece o mesmo ente...
# 469   Senhora Solicitante , Em atenção à solicitação...
# 538   Prezado Sr . Marques , Agradecemos seu contato...
# 6636  Prezado Sr . Obrigado por utilizar esse canal ...
# 5820  Prezado Senhor , Compete à Anatel a administra...
# 1047  Prezada Aline . Consultamos documentos enviado...
# 1219  Prezada, Atualmente, o IF Baiano  possui 27 có...
#
#                                                sentence
# 4119  Prezado a Cidadão ã , 1 . Conforme solicitação...
# 3477  Prezado Senhor , O processo mencionado nademan...
# 4322   Segue respostas deste Setor . RESPOSTA A PEDI...
# 3349  Prezado Senhor Carlos , Permanece o mesmo ente...
# 469   Senhora Solicitante , Em atenção à solicitação...
# 538   Prezado Sr . Marques , Agradecemos seu contato...
# 6636  Prezado Sr . Obrigado por utilizar esse canal ...
# 5820  Prezado Senhor , Compete à Anatel a administra...
# 1047  Prezada Aline . Consultamos documentos enviado...
# 1219  Prezada, Atualmente, o IF Baiano  possui 27 có...

# %%
# Looking lengths
lengths = [X_train.sentence.apply(lambda x: len(x.split(' ')))]
perc =[.25, .50, .75, .80, .85, .90, .91, .92, .93, .94, .95, .96, .97, .98, .99] 
lengths[0].describe(percentiles = perc)
# Out:
# count    6982.000000
# mean      166.246777
# std       163.302486
# min         1.000000
# 25%        56.000000
# 50%       120.000000
# 75%       225.000000
# 80%       255.000000
# 85%       290.000000
# 90%       354.000000
# 91%       366.000000
# 92%       384.040000
# 93%       405.000000
# 94%       431.000000
# 95%       459.000000
# 96%       499.000000
# 97%       539.570000
# 98%       643.520000
# 99%       784.520000
# max      1885.000000
# Name: sentence, dtype: float64

# %% [markdown]
# # w2v Model for Embedding Layer

# %%
#w2v_cbow_esic_model=KeyedVectors.load(os.path.join(w2v_models_path,'word2vec_sg_hs_DetalhamentoSolicitacao_all_sentences_128.model'))
w2v_cbow_nilc_model=KeyedVectors.load_word2vec_format(os.path.join(w2v_models_path,'cbow_s300.txt'))

# %%
pretrained_weights = w2v_cbow_nilc_model.wv.syn0
print(pretrained_weights.shape)
max_num_words = pretrained_weights.shape[0]
embed_size = pretrained_weights.shape[1]
# Out:
# (929606, 300)
# C:\Users\arthu\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """Entry point for launching an IPython kernel.
# C:\Users\arthu\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `syn0` (Attribute will be removed in 4.0.0, use self.vectors instead).
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# # Data Prep

# %%
max_length=128

# Define tokenizer and fit train data
t = Tokenizer(num_words=max_num_words)
t.fit_on_texts(X_train['sentence'].append(X_test['sentence']))
word_index = t.word_index
vocab_size = len(word_index) + 1
print('Found %s unique tokens.' % len(word_index))
    
def get_seqs(text):    
    sequences = t.texts_to_sequences(text)
    padded_sequences = pad_sequences(sequences, maxlen=max_length, padding='post')
    return padded_sequences
# Out:
# Found 36763 unique tokens.

# %%
# prepare target
def prepare_targets(y_train, y_test):
    le = LabelEncoder()
    le.fit(y_train)
    y_train_enc = le.transform(y_train)
    y_test_enc = le.transform(y_test)
    if binary:
        return y_train_enc, y_test_enc
    else:
        return pd.get_dummies(y_train_enc), pd.get_dummies(y_test_enc)

# %%
# X and Y
label_train, label_test = prepare_targets(y_train.label.values, y_test.label.values)
num_labels = len(set(label_train))
input_train = get_seqs(X_train.sentence)
input_test = get_seqs(X_test.sentence)

# %% [markdown]
# # Modeling

# %%
embedding_matrix = np.zeros((vocab_size, embed_size))
for word, i in t.word_index.items():
    try:
        embedding_vector = w2v_cbow_nilc_model.wv.__getitem__(word)
        if embedding_vector is not None:
            embedding_matrix[i] = embedding_vector
    # Words not in vocab -> Frequency less than 5 word
    except KeyError as e:
        print(e)
# Out:
# C:\Users\arthu\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:4: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   after removing the cwd from sys.path.
# "word 'à' not in vocabulary"
# "word '12' not in vocabulary"
# "word '1' not in vocabulary"
# "word '7' not in vocabulary"
# "word '10' not in vocabulary"
# "word '2' not in vocabulary"
# "word '2012' not in vocabulary"
# "word '724' not in vocabulary"
# "word 'às' not in vocabulary"
# "word '2011' not in vocabulary"
# "word '527' not in vocabulary"
# "word '3' not in vocabulary"
# "word '2016' not in vocabulary"
# "word '2015' not in vocabulary"
# "word '4' not in vocabulary"
# "word '21' not in vocabulary"
# "word '2017' not in vocabulary"
# "word '5' not in vocabulary"
# "word '0800' not in vocabulary"
# "word '2014' not in vocabulary"
# "word '15' not in vocabulary"
# "word '–' not in vocabulary"
# "word '11' not in vocabulary"
# "word '18' not in vocabulary"
# "word 'acessoainformacao' not in vocabulary"
# "word '1ª' not in vocabulary"
# "word '61' not in vocabulary"
# "word '13' not in vocabulary"
# "word '16' not in vocabulary"
# "word '08' not in vocabulary"
# "word '07' not in vocabulary"
# "word '01' not in vocabulary"
# "word '2013' not in vocabulary"
# "word '8' not in vocabulary"
# "word '24' not in vocabulary"
# "word '\xa0' not in vocabulary"
# "word '6' not in vocabulary"
# "word '19' not in vocabulary"
# "word '04' not in vocabulary"
# "word '03' not in vocabulary"
# "word '20' not in vocabulary"
# "word '02' not in vocabulary"
# "word '726' not in vocabulary"
# "word '1º' not in vocabulary"
# "word '0101' not in vocabulary"
# "word '725' not in vocabulary"
# "word '14' not in vocabulary"
# "word '7474' not in vocabulary"
# "word '05' not in vocabulary"
# "word '900' not in vocabulary"
# "word 'naseção' not in vocabulary"
# "word '30' not in vocabulary"
# "word '9' not in vocabulary"
# "word '22' not in vocabulary"
# "word '06' not in vocabulary"
# "word '09' not in vocabulary"
# "word '17' not in vocabulary"
# "word '55' not in vocabulary"
# "word '70' not in vocabulary"
# "word '31' not in vocabulary"
# "word '2010' not in vocabulary"
# "word '60' not in vocabulary"
# "word '2º' not in vocabulary"
# "word '7º' not in vocabulary"
# "word 'faleconosco' not in vocabulary"
# "word '5º' not in vocabulary"
# "word '3º' not in vocabulary"
# "word '29' not in vocabulary"
# "word '2009' not in vocabulary"
# "word '23' not in vocabulary"
# "word '28' not in vocabulary"
# "word '25' not in vocabulary"
# "word '135' not in vocabulary"
# "word '1o' not in vocabulary"
# "word 'napáginawww' not in vocabulary"
# "word '2008' not in vocabulary"
# "word '27' not in vocabulary"
# "word '70610' not in vocabulary"
# "word '327' not in vocabulary"
# "word '2ª' not in vocabulary"
# "word '2007' not in vocabulary"
# "word '908' not in vocabulary"
# "word 'páginanainternet' not in vocabulary"
# "word 'nainternet' not in vocabulary"
# "word '26' not in vocabulary"
# "word '2004' not in vocabulary"
# "word '4º' not in vocabulary"
# "word '2006' not in vocabulary"
# "word 'registrato' not in vocabulary"
# "word '35' not in vocabulary"
# "word '37' not in vocabulary"
# "word '2o' not in vocabulary"
# "word 'orientacao' not in vocabulary"
# "word '6°' not in vocabulary"
# "word 'determinao' not in vocabulary"
# "word '173' not in vocabulary"
# "word '7724' not in vocabulary"
# "word '7h30' not in vocabulary"
# "word '2005' not in vocabulary"
# "word '145' not in vocabulary"
# "word '642' not in vocabulary"
# "word '19h30' not in vocabulary"
# "word '9782' not in vocabulary"
# "word '50' not in vocabulary"
# "word '818' not in vocabulary"
# "word '2001' not in vocabulary"
# "word '40' not in vocabulary"
# "word 'napáginada' not in vocabulary"
# "word '6º' not in vocabulary"
# "word '90' not in vocabulary"
# "word 'scen' not in vocabulary"
# "word '12527' not in vocabulary"
# "word '112' not in vocabulary"
# "word '1999' not in vocabulary"
# "word '41' not in vocabulary"
# "word '2000' not in vocabulary"
# "word '2018' not in vocabulary"
# "word '92' not in vocabulary"
# "word '91' not in vocabulary"
# "word '2002' not in vocabulary"
# "word '100' not in vocabulary"
# "word 'sicnetweb' not in vocabulary"
# "word 'segrt' not in vocabulary"
# "word '§1º' not in vocabulary"
# "word 'deati' not in vocabulary"
# "word '00077' not in vocabulary"
# "word '80' not in vocabulary"
# "word '97' not in vocabulary"
# "word 'nahipótese' not in vocabulary"
# "word '2024' not in vocabulary"
# "word '0001' not in vocabulary"
# "word 'ccivil' not in vocabulary"
# "word '2003' not in vocabulary"
# "word '233' not in vocabulary"
# "word '84' not in vocabulary"
# "word '65' not in vocabulary"
# "word 'www2' not in vocabulary"
# "word '2025' not in vocabulary"
# "word '040' not in vocabulary"
# "word '003' not in vocabulary"
# "word '22h' not in vocabulary"
# "word 'sicbb' not in vocabulary"
# "word '51' not in vocabulary"
# "word '96' not in vocabulary"
# "word 'portalfab' not in vocabulary"
# "word '3201' not in vocabulary"
# "word 'naoportunidade' not in vocabulary"
# "word '3949' not in vocabulary"
# "word 'àquela' not in vocabulary"
# "word '250' not in vocabulary"
# "word '166' not in vocabulary"
# "word 'www1' not in vocabulary"
# "word '”' not in vocabulary"
# "word '9º' not in vocabulary"
# "word '8h' not in vocabulary"
# "word '23480' not in vocabulary"
# "word '70200' not in vocabulary"
# "word 'natela' not in vocabulary"
# "word '800' not in vocabulary"
# "word '93' not in vocabulary"
# "word 'decdp' not in vocabulary"
# "word '32' not in vocabulary"
# "word 'solicitacao' not in vocabulary"
# "word 'c3' not in vocabulary"
# "word '18h' not in vocabulary"
# "word '1995' not in vocabulary"
# "word 'naportaria' not in vocabulary"
# "word '95' not in vocabulary"
# "word '48700' not in vocabulary"
# "word 'qrsta' not in vocabulary"
# "word '150' not in vocabulary"
# "word 'naouvidoria' not in vocabulary"
# "word '34' not in vocabulary"
# "word 'portaltransparencia' not in vocabulary"
# "word '3315' not in vocabulary"
# "word '45' not in vocabulary"
# "word '8º' not in vocabulary"
# "word '33' not in vocabulary"
# "word '42' not in vocabulary"
# "word '88' not in vocabulary"
# "word '1990' not in vocabulary"
# "word '70068' not in vocabulary"
# "word '1988' not in vocabulary"
# "word '1°' not in vocabulary"
# "word '2028' not in vocabulary"
# "word '85' not in vocabulary"
# "word '62' not in vocabulary"
# "word '81' not in vocabulary"
# "word '83' not in vocabulary"
# "word '1996' not in vocabulary"
# "word '57' not in vocabulary"
# "word '69' not in vocabulary"
# "word 'cgpge' not in vocabulary"
# "word '36' not in vocabulary"
# "word '48500' not in vocabulary"
# "word '0xx61' not in vocabulary"
# "word '74' not in vocabulary"
# "word '99' not in vocabulary"
# "word 'desarrazoados' not in vocabulary"
# "word '1101' not in vocabulary"
# "word '3107' not in vocabulary"
# "word '912' not in vocabulary"
# "word '045' not in vocabulary"
# "word '66' not in vocabulary"
# "word '216' not in vocabulary"
# "word 'páginade' not in vocabulary"
# "word '86' not in vocabulary"
# "word '001' not in vocabulary"
# "word '25000' not in vocabulary"
# "word '180' not in vocabulary"
# "word 'progesp' not in vocabulary"
# "word 'naconstituição' not in vocabulary"
# "word '54' not in vocabulary"
# "word '76' not in vocabulary"
# "word '53' not in vocabulary"
# "word 'ato2011' not in vocabulary"
# "word '46' not in vocabulary"
# "word '3305' not in vocabulary"
# "word '52' not in vocabulary"
# "word 'a1' not in vocabulary"
# "word '80200' not in vocabulary"
# "word '71' not in vocabulary"
# "word 'pela\xa0gerência' not in vocabulary"
# "word '38' not in vocabulary"
# "word 'naavenida' not in vocabulary"
# "word 'orientacoes' not in vocabulary"
# "word '48' not in vocabulary"
# "word '73' not in vocabulary"
# "word '2029' not in vocabulary"
# "word '70910' not in vocabulary"
# "word '2710' not in vocabulary"
# "word 'napáginado' not in vocabulary"
# "word 'nadata' not in vocabulary"
# "word 'naaba' not in vocabulary"
# "word '3o' not in vocabulary"
# "word '1998' not in vocabulary"
# "word '67' not in vocabulary"
# "word 'naunidade' not in vocabulary"
# "word '105' not in vocabulary"
# "word '58' not in vocabulary"
# "word '2020' not in vocabulary"
# "word '1997' not in vocabulary"
# "word '394' not in vocabulary"
# "word '010' not in vocabulary"
# "word 'ebtt' not in vocabulary"
# "word '03000' not in vocabulary"
# "word 'd7724' not in vocabulary"
# "word '39' not in vocabulary"
# "word '500' not in vocabulary"
# "word '5°' not in vocabulary"
# "word '44' not in vocabulary"
# "word '4o' not in vocabulary"
# "word '01590' not in vocabulary"
# "word 'licitacoes' not in vocabulary"
# "word '101' not in vocabulary"
# "word '1491' not in vocabulary"
# "word '3318' not in vocabulary"
# "word '60502' not in vocabulary"
# "word '031' not in vocabulary"
# "word 'determinaque' not in vocabulary"
# "word 'nainstituição' not in vocabulary"
# "word '25820' not in vocabulary"
# "word '002' not in vocabulary"
# "word '98' not in vocabulary"
# "word '1012' not in vocabulary"
# "word 'determinaa' not in vocabulary"
# "word '1993' not in vocabulary"
# "word '1991' not in vocabulary"
# "word 'resolucoes' not in vocabulary"
# "word '140' not in vocabulary"
# "word 'páginada' not in vocabulary"
# "word '1994' not in vocabulary"
# "word '79' not in vocabulary"
# "word '0297' not in vocabulary"
# "word '2021' not in vocabulary"
# "word '1331' not in vocabulary"
# "word 'indeferimos' not in vocabulary"
# "word '56' not in vocabulary"
# "word '89' not in vocabulary"
# "word 'naopção' not in vocabulary"
# "word '271' not in vocabulary"
# "word '131' not in vocabulary"
# "word 'publicacoes' not in vocabulary"
# "word '7755' not in vocabulary"
# "word '102' not in vocabulary"
# "word '110' not in vocabulary"
# "word '044' not in vocabulary"
# "word '63' not in vocabulary"
# "word '0021' not in vocabulary"
# "word 'sefic' not in vocabulary"
# "word 'nasúmula' not in vocabulary"
# "word '43' not in vocabulary"
# "word 'shtm' not in vocabulary"
# "word '94' not in vocabulary"
# "word '2032' not in vocabulary"
# "word '111' not in vocabulary"
# "word '87' not in vocabulary"
# "word '49' not in vocabulary"
# "word '72' not in vocabulary"
# "word 'pessoafisica' not in vocabulary"
# "word '232' not in vocabulary"
# "word '64' not in vocabulary"
# "word '784' not in vocabulary"
# "word '4005' not in vocabulary"
# "word 'nabarra' not in vocabulary"
# "word '062' not in vocabulary"
# "word 'napáginahttp' not in vocabulary"
# "word '070' not in vocabulary"
# "word 'siconv' not in vocabulary"
# "word 'nareferida' not in vocabulary"
# "word 'protocolointegrado' not in vocabulary"
# "word '68' not in vocabulary"
# "word '3312' not in vocabulary"
# "word 'naagência' not in vocabulary"
# "word '3316' not in vocabulary"
# "word 'cgcp' not in vocabulary"
# "word 'joseleno' not in vocabulary"
# "word '20h' not in vocabulary"
# "word '59' not in vocabulary"
# "word 'daeb' not in vocabulary"
# "word '200' not in vocabulary"
# "word '15414' not in vocabulary"
# "word '251' not in vocabulary"
# "word 'arquivonacional' not in vocabulary"
# "word 'isencao' not in vocabulary"
# "word '156' not in vocabulary"
# "word 'inepdata' not in vocabulary"
# "word '50650' not in vocabulary"
# "word 'copeiragem' not in vocabulary"
# "word 'páginainicial' not in vocabulary"
# "word '404' not in vocabulary"
# "word '202' not in vocabulary"
# "word '2228' not in vocabulary"
# "word '78' not in vocabulary"
# "word '600' not in vocabulary"
# "word '99923' not in vocabulary"
# "word '0111' not in vocabulary"
# "word '331' not in vocabulary"
# "word 'cogep' not in vocabulary"
# "word 'audin' not in vocabulary"
# "word 'nasede' not in vocabulary"
# "word '3ª' not in vocabulary"
# "word '20031' not in vocabulary"
# "word 'reginaribeiro' not in vocabulary"
# "word '47' not in vocabulary"
# "word 'conlegis' not in vocabulary"
# "word '10ª' not in vocabulary"
# "word '205' not in vocabulary"
# "word '99901' not in vocabulary"
# "word '198' not in vocabulary"
# "word 'gadip' not in vocabulary"
# "word 'nasecretaria' not in vocabulary"
# "word 'restituicao' not in vocabulary"
# "word '2233' not in vocabulary"
# "word '103' not in vocabulary"
# "word 'aeronauticaoficial' not in vocabulary"
# "word 'forcaaereablog' not in vocabulary"
# "word '051' not in vocabulary"
# "word '666' not in vocabulary"
# "word '2102' not in vocabulary"
# "word '9h' not in vocabulary"
# "word 'eping' not in vocabulary"
# "word '120' not in vocabulary"
# "word '075' not in vocabulary"
# "word 'naguia' not in vocabulary"
# "word 'portalsaude' not in vocabulary"
# "word '77' not in vocabulary"
# "word 'mcidades' not in vocabulary"
# "word 'napáginaprincipal' not in vocabulary"
# "word 'pela\xa0coordenação' not in vocabulary"
# "word '213' not in vocabulary"
# "word '616161' not in vocabulary"
# "word 'naplanilha' not in vocabulary"
# "word '902' not in vocabulary"
# "word '701' not in vocabulary"
# "word 'namodalidade' not in vocabulary"
# "word '2108' not in vocabulary"
# "word 'páginado' not in vocabulary"
# "word 'nasuperintendência' not in vocabulary"
# "word '01390' not in vocabulary"
# "word '75' not in vocabulary"
# "word '5o' not in vocabulary"
# "word '1976' not in vocabulary"
# "word '149' not in vocabulary"
# "word 'comprasnet' not in vocabulary"
# "word 'declara2003informa1aviso' not in vocabulary"
# "word '204' not in vocabulary"
# "word '3216' not in vocabulary"
# "word 'censosuperior' not in vocabulary"
# "word '82' not in vocabulary"
# "word 'nadeclaração' not in vocabulary"
# "word 'cggp' not in vocabulary"
# "word '1677' not in vocabulary"
# "word '0758' not in vocabulary"
# "word '350' not in vocabulary"
# "word '1332' not in vocabulary"
# "word '2°' not in vocabulary"
# "word '2590' not in vocabulary"
# "word '§2º' not in vocabulary"
# "word '1989' not in vocabulary"
# "word '400' not in vocabulary"
# "word '17h' not in vocabulary"
# "word '160' not in vocabulary"
# "word '020' not in vocabulary"
# "word '13º' not in vocabulary"
# "word '598' not in vocabulary"
# "word '711' not in vocabulary"
# "word '106' not in vocabulary"
# "word '227' not in vocabulary"
# "word 'nainstrução' not in vocabulary"
# "word '30575' not in vocabulary"
# "word '240' not in vocabulary"
# "word '4ª' not in vocabulary"
# "word '416' not in vocabulary"
# "word '7066' not in vocabulary"
# "word 'licitacao' not in vocabulary"
# "word '8378' not in vocabulary"
# "word 'certidoes' not in vocabulary"
# "word '1992' not in vocabulary"
# "word '158' not in vocabulary"
# "word 'sistec' not in vocabulary"
# "word 'denegatórias' not in vocabulary"
# "word 'marcassi' not in vocabulary"
# "word '7835' not in vocabulary"
# "word '207' not in vocabulary"
# "word '159' not in vocabulary"
# "word '074' not in vocabulary"
# "word '109' not in vocabulary"
# "word 'naapresentação' not in vocabulary"
# "word 'pisp650' not in vocabulary"
# "word 'tamilis' not in vocabulary"
# "word '520' not in vocabulary"
# "word 'naferramenta' not in vocabulary"
# "word '12h' not in vocabulary"
# "word '1966' not in vocabulary"
# "word '099' not in vocabulary"
# "word '1582' not in vocabulary"
# "word '000679' not in vocabulary"
# "word '48610' not in vocabulary"
# "word '021' not in vocabulary"
# "word '2317' not in vocabulary"
# "word '2245' not in vocabulary"
# "word 'culturadigital' not in vocabulary"
# "word 'servicoscultura' not in vocabulary"
# "word '2109' not in vocabulary"
# "word '20261' not in vocabulary"
# "word '3218' not in vocabulary"
# "word '702' not in vocabulary"
# "word 'nademanda' not in vocabulary"
# "word '125' not in vocabulary"
# "word 'ppgd' not in vocabulary"
# "word '320' not in vocabulary"
# "word 'nasusep' not in vocabulary"
# "word 'reginasantanasic' not in vocabulary"
# "word '3314' not in vocabulary"
# "word '177' not in vocabulary"
# "word 'dlog' not in vocabulary"
# "word '08650' not in vocabulary"
# "word 'isencoes' not in vocabulary"
# "word 'naauditoria' not in vocabulary"
# "word '130' not in vocabulary"
# "word '820' not in vocabulary"
# "word 'nagerência' not in vocabulary"
# "word '851' not in vocabulary"
# "word '00075' not in vocabulary"
# "word '651' not in vocabulary"
# "word '9699' not in vocabulary"
# "word 'àquele' not in vocabulary"
# "word 'cgrh' not in vocabulary"
# "word '9784' not in vocabulary"
# "word '00058' not in vocabulary"
# "word '169' not in vocabulary"
# "word '5560' not in vocabulary"
# "word '119' not in vocabulary"
# "word 'naesfera' not in vocabulary"
# "word '172' not in vocabulary"
# "word '514' not in vocabulary"
# "word '08850' not in vocabulary"
# "word 'naíntegra' not in vocabulary"
# "word 'namenor' not in vocabulary"
# "word 'sumulas' not in vocabulary"
# "word 'sisbacenweb' not in vocabulary"
# "word '19h' not in vocabulary"
# "word 'instrucoes' not in vocabulary"
# "word '“anexos”' not in vocabulary"
# "word 'nacarta' not in vocabulary"
# "word '§3º' not in vocabulary"
# "word '1985' not in vocabulary"
# "word 'prodegesp' not in vocabulary"
# "word '136' not in vocabulary"
# "word '2030' not in vocabulary"
# "word 'divgp' not in vocabulary"
# "word 'nareitoria' not in vocabulary"
# "word 'deofi' not in vocabulary"
# "word 'gespública' not in vocabulary"
# "word 'portaldatransparencia' not in vocabulary"
# "word '108' not in vocabulary"
# "word 'mjsp' not in vocabulary"
# "word 'inscricao' not in vocabulary"
# "word '206' not in vocabulary"
# "word 'pqa' not in vocabulary"
# "word '9°' not in vocabulary"
# "word '182' not in vocabulary"
# "word 'sigaa' not in vocabulary"
# "word '080' not in vocabulary"
# "word 'naconsulta' not in vocabulary"
# "word '378' not in vocabulary"
# "word 'pequenaempresa' not in vocabulary"
# "word 'natransação' not in vocabulary"
# "word '4009' not in vocabulary"
# "word '7860' not in vocabulary"
# "word '142' not in vocabulary"
# "word 'nafunai' not in vocabulary"
# "word '20289699' not in vocabulary"
# "word 'pr4' not in vocabulary"
# "word 'cget' not in vocabulary"
# "word '20218378' not in vocabulary"
# "word 'naarregimentação' not in vocabulary"
# "word 'siconfi' not in vocabulary"
# "word 'eletropar' not in vocabulary"
# "word '20297836' not in vocabulary"
# "word '7834' not in vocabulary"
# "word '015' not in vocabulary"
# "word '612' not in vocabulary"
# "word 'dirplad' not in vocabulary"
# "word '016' not in vocabulary"
# "word 'cadsenha' not in vocabulary"
# "word 'pdti' not in vocabulary"
# "word 'dadosefatos' not in vocabulary"
# "word 'sepn' not in vocabulary"
# "word '545' not in vocabulary"
# "word '25351' not in vocabulary"
# "word '913' not in vocabulary"
# "word '3521' not in vocabulary"
# "word 'narelação' not in vocabulary"
# "word '115' not in vocabulary"
# "word '116' not in vocabulary"
# "word '2101' not in vocabulary"
# "word 'siass' not in vocabulary"
# "word '830' not in vocabulary"
# "word '129041' not in vocabulary"
# "word 'judicie' not in vocabulary"
# "word '0748' not in vocabulary"
# "word '20de' not in vocabulary"
# "word '1973' not in vocabulary"
# "word '321' not in vocabulary"
# "word 'vigep' not in vocabulary"
# "word '011' not in vocabulary"
# "word 'bibliotecavirtual' not in vocabulary"
# "word '20120510104907' not in vocabulary"
# "word '155' not in vocabulary"
# "word '292' not in vocabulary"
# "word 'salicnet' not in vocabulary"
# "word '20090' not in vocabulary"
# "word '70070' not in vocabulary"
# "word '212' not in vocabulary"
# "word 'contribuicao' not in vocabulary"
# "word 'a3o' not in vocabulary"
# "word '54800' not in vocabulary"
# "word '14h' not in vocabulary"
# "word '3358' not in vocabulary"
# "word '08007021111' not in vocabulary"
# "word 'dirad' not in vocabulary"
# "word '8080' not in vocabulary"
# "word 'ferlim' not in vocabulary"
# "word 'raint' not in vocabulary"
# "word '09641' not in vocabulary"
# "word '70760' not in vocabulary"
# "word '§6º' not in vocabulary"
# "word '261' not in vocabulary"
# "word 'reportamo' not in vocabulary"
# "word '2179' not in vocabulary"
# "word '168' not in vocabulary"
# "word 'nabusca' not in vocabulary"
# "word 'sgtes' not in vocabulary"
# "word 'questionarios' not in vocabulary"
# "word '300' not in vocabulary"
# "word '1072' not in vocabulary"
# "word '2022' not in vocabulary"
# "word 'ouvidoriadoservidor' not in vocabulary"
# "word '163' not in vocabulary"
# "word 'nasolicitação' not in vocabulary"
# "word 'cprod' not in vocabulary"
# "word '7727' not in vocabulary"
# "word 'registrarmanifestacaobs' not in vocabulary"
# "word 'supervisonado' not in vocabulary"
# "word '99920' not in vocabulary"
# "word '3319' not in vocabulary"
# "word 'nabiblioteca' not in vocabulary"
# "word 'contribuicoes' not in vocabulary"
# "word '1964' not in vocabulary"
# "word 'depam' not in vocabulary"
# "word 'simulacao' not in vocabulary"
# "word '091' not in vocabulary"
# "word '360' not in vocabulary"
# "word '871' not in vocabulary"
# "word '“art' not in vocabulary"
# "word 'cgiae' not in vocabulary"
# "word '7065' not in vocabulary"
# "word 'sipeagro' not in vocabulary"
# "word 'dides' not in vocabulary"
# "word 'nº23480' not in vocabulary"
# "word 'páginaeletrônica' not in vocabulary"
# "word '128' not in vocabulary"
# "word '6602' not in vocabulary"
# "word 'napáginade' not in vocabulary"
# "word '465' not in vocabulary"
# "word 'dcomp' not in vocabulary"
# "word 'cgesp' not in vocabulary"
# "word '3232' not in vocabulary"
# "word '510' not in vocabulary"
# "word '917' not in vocabulary"
# "word '603' not in vocabulary"
# "word 'nacentral' not in vocabulary"
# "word '2566' not in vocabulary"
# "word '2019' not in vocabulary"
# "word 'portal2' not in vocabulary"
# "word '534' not in vocabulary"
# "word '1968' not in vocabulary"
# "word '1978' not in vocabulary"
# "word '1969' not in vocabulary"
# "word 'finbra' not in vocabulary"
# "word '208' not in vocabulary"
# "word '118' not in vocabulary"
# "word '4623' not in vocabulary"
# "word '6333' not in vocabulary"
# "word '6o' not in vocabulary"
# "word '141' not in vocabulary"
# "word 'wwwanp' not in vocabulary"
# "word '742' not in vocabulary"
# "word '303' not in vocabulary"
# "word '20091' not in vocabulary"
# "word 'seps' not in vocabulary"
# "word '713' not in vocabulary"
# "word '153' not in vocabulary"
# "word '6ª' not in vocabulary"
# "word '0207' not in vocabulary"
# "word '004' not in vocabulary"
# "word 'ww2' not in vocabulary"
# "word '235' not in vocabulary"
# "word '224' not in vocabulary"
# "word 'aerodromos' not in vocabulary"
# "word '7°' not in vocabulary"
# "word '460' not in vocabulary"
# "word '124' not in vocabulary"
# "word '304' not in vocabulary"
# "word 'pdet' not in vocabulary"
# "word '2510' not in vocabulary"
# "word '7777' not in vocabulary"
# "word '569' not in vocabulary"
# "word '10º' not in vocabulary"
# "word '9656' not in vocabulary"
# "word '188' not in vocabulary"
# "word '984' not in vocabulary"
# "word '170' not in vocabulary"
# "word '139' not in vocabulary"
# "word '094' not in vocabulary"
# "word '18600' not in vocabulary"
# "word 'cgcp1' not in vocabulary"
# "word '658' not in vocabulary"
# "word 'naprova' not in vocabulary"
# "word '146' not in vocabulary"
# "word 'igovti' not in vocabulary"
# "word '01500' not in vocabulary"
# "word '002172' not in vocabulary"
# "word 'ggali' not in vocabulary"
# "word 'nareceita' not in vocabulary"
# "word '583' not in vocabulary"
# "word 'viacao' not in vocabulary"
# "word '367' not in vocabulary"
# "word '132' not in vocabulary"
# "word '256' not in vocabulary"
# "word 'noticianoticiastf' not in vocabulary"
# "word 're598099gm' not in vocabulary"
# "word 'anapoderá' not in vocabulary"
# "word '025' not in vocabulary"
# "word '16h' not in vocabulary"
# "word '48513' not in vocabulary"
# "word '3629' not in vocabulary"
# "word '229' not in vocabulary"
# "word '22221' not in vocabulary"
# "word '2976' not in vocabulary"
# "word '6611' not in vocabulary"
# "word '7993' not in vocabulary"
# "word '6253' not in vocabulary"
# "word '70390' not in vocabulary"
# "word '5509' not in vocabulary"
# "word '929' not in vocabulary"
# "word 'a7' not in vocabulary"
# "word '024' not in vocabulary"
# "word '230' not in vocabulary"
# "word '16853' not in vocabulary"
# "word '161' not in vocabulary"
# "word '014' not in vocabulary"
# "word '048' not in vocabulary"
# "word 'prppg' not in vocabulary"
# "word '372' not in vocabulary"
# "word '1986' not in vocabulary"
# "word 'trabalhoerendimento' not in vocabulary"
# "word 'comprasgovernamentais' not in vocabulary"
# "word 'portalcidadao' not in vocabulary"
# "word 'cadsis' not in vocabulary"
# "word 'dadoscadastro' not in vocabulary"
# "word 'hupes' not in vocabulary"
# "word '344' not in vocabulary"
# "word 'idarea' not in vocabulary"
# "word '“a' not in vocabulary"
# "word 'naprópria' not in vocabulary"
# "word '524' not in vocabulary"
# "word '234' not in vocabulary"
# "word 'autoseg' not in vocabulary"
# "word 'cgti' not in vocabulary"
# "word 'bgcaged' not in vocabulary"
# "word 'sgep' not in vocabulary"
# "word 'infracoes' not in vocabulary"
# "word '60584' not in vocabulary"
# "word 'biolange' not in vocabulary"
# "word '167' not in vocabulary"
# "word 'deaex' not in vocabulary"
# "word 'aans' not in vocabulary"
# "word '137' not in vocabulary"
# "word '192' not in vocabulary"
# "word '117' not in vocabulary"
# "word '147' not in vocabulary"
# "word '683' not in vocabulary"
# "word '450' not in vocabulary"
# "word '019' not in vocabulary"
# "word '013' not in vocabulary"
# "word 'atendcontrib' not in vocabulary"
# "word 'unidatendimento' not in vocabulary"
# "word 'centroatendimento' not in vocabulary"
# "word 'assinaa' not in vocabulary"
# "word '178' not in vocabulary"
# "word '134' not in vocabulary"
# "word '3247' not in vocabulary"
# "word 'compensacao' not in vocabulary"
# "word 'qselecao' not in vocabulary"
# "word 'georgilene' not in vocabulary"
# "word 'sufer' not in vocabulary"
# "word '189' not in vocabulary"
# "word '220' not in vocabulary"
# "word 'páginaa' not in vocabulary"
# "word 'nacópia' not in vocabulary"
# "word 'devit' not in vocabulary"
# "word '195' not in vocabulary"
# "word 'narua' not in vocabulary"
# "word '§4º' not in vocabulary"
# "word '1967' not in vocabulary"
# "word '730' not in vocabulary"
# "word '317' not in vocabulary"
# "word '333' not in vocabulary"
# "word 'siorg' not in vocabulary"
# "word 'consultasdf' not in vocabulary"
# "word 'naplataforma' not in vocabulary"
# "word '0100' not in vocabulary"
# "word '121' not in vocabulary"
# "word '3253' not in vocabulary"
# "word '3391' not in vocabulary"
# "word 'www3' not in vocabulary"
# "word '1111' not in vocabulary"
# "word 'geól' not in vocabulary"
# "word 'naanatel' not in vocabulary"
# "word 'gepes' not in vocabulary"
# "word 'scdc' not in vocabulary"
# "word '944' not in vocabulary"
# "word '152' not in vocabulary"
# "word '305' not in vocabulary"
# "word '705' not in vocabulary"
# "word 'disciplinao' not in vocabulary"
# "word 'naanvisa' not in vocabulary"
# "word '978' not in vocabulary"
# "word '290' not in vocabulary"
# "word '3360' not in vocabulary"
# "word '164' not in vocabulary"
# "word '4°' not in vocabulary"
# "word '190' not in vocabulary"
# "word '990' not in vocabulary"
# "word 'uasg' not in vocabulary"
# "word '0800611535' not in vocabulary"
# "word '8239' not in vocabulary"
# "word '4559' not in vocabulary"
# "word '3411' not in vocabulary"
# "word 'megp' not in vocabulary"
# "word '127' not in vocabulary"
# "word 'dnitcidadao' not in vocabulary"
# "word '802' not in vocabulary"
# "word '3311' not in vocabulary"
# "word '267' not in vocabulary"
# "word 'zopacas' not in vocabulary"
# "word 'nafolha' not in vocabulary"
# "word 'degep' not in vocabulary"
# "word 'atualizacao' not in vocabulary"
# "word '005' not in vocabulary"
# "word '357' not in vocabulary"
# "word '5242' not in vocabulary"
# "word '511' not in vocabulary"
# "word 'depreps' not in vocabulary"
# "word 'ggpes' not in vocabulary"
# "word 'dadmp' not in vocabulary"
# "word '126' not in vocabulary"
# "word 'pessoafisicaejuridica' not in vocabulary"
# "word 'sitfiscodigoacesso' not in vocabulary"
# "word '9rfb' not in vocabulary"
# "word '104' not in vocabulary"
# "word 'dilic' not in vocabulary"
# "word 'lucenados' not in vocabulary"
# "word '11º' not in vocabulary"
# "word '035' not in vocabulary"
# "word 'macroestratégicas' not in vocabulary"
# "word 'sisouvidormp' not in vocabulary"
# "word '846' not in vocabulary"
# "word '629' not in vocabulary"
# "word '619' not in vocabulary"
# "word '211' not in vocabulary"
# "word 'àqueles' not in vocabulary"
# "word '330' not in vocabulary"
# "word '3176' not in vocabulary"
# "word '254' not in vocabulary"
# "word '1987' not in vocabulary"
# "word 'nanorma' not in vocabulary"
# "word 'ggtox' not in vocabulary"
# "word 'lanaturner' not in vocabulary"
# "word '940' not in vocabulary"
# "word '122' not in vocabulary"
# "word '4374' not in vocabulary"
# "word 'funcionade' not in vocabulary"
# "word 'neabi' not in vocabulary"
# "word '1700' not in vocabulary"
# "word 'perguntao' not in vocabulary"
# "word 'sisouvidor' not in vocabulary"
# "word '047' not in vocabulary"
# "word '2182' not in vocabulary"
# "word '772' not in vocabulary"
# "word '20246060' not in vocabulary"
# "word '8112' not in vocabulary"
# "word '590' not in vocabulary"
# "word '565' not in vocabulary"
# "word '1980' not in vocabulary"
# "word '13h' not in vocabulary"
# "word '050' not in vocabulary"
# "word '425' not in vocabulary"
# "word '228' not in vocabulary"
# "word '023' not in vocabulary"
# "word '043' not in vocabulary"
# "word '729' not in vocabulary"
# "word '414' not in vocabulary"
# "word 'cgsi' not in vocabulary"
# "word 'sigrh' not in vocabulary"
# "word '3283' not in vocabulary"
# "word '383' not in vocabulary"
# "word 'www12' not in vocabulary"
# "word '3449' not in vocabulary"
# "word '788' not in vocabulary"
# "word '503' not in vocabulary"
# "word '09009' not in vocabulary"
# "word '656' not in vocabulary"
# "word '26p' not in vocabulary"
# "word '053' not in vocabulary"
# "word 'cocfp' not in vocabulary"
# "word 'nº1' not in vocabulary"
# "word '901' not in vocabulary"
# "word 'golimumabe' not in vocabulary"
# "word 'suap' not in vocabulary"
# "word '215' not in vocabulary"
# "word 'proae' not in vocabulary"
# "word '144' not in vocabulary"
# "word 'nalocalização' not in vocabulary"
# "word '114' not in vocabulary"
# "word 'bdgd' not in vocabulary"
# "word '123' not in vocabulary"
# "word '210' not in vocabulary"
# "word 'cgrl' not in vocabulary"
# "word 'gdac' not in vocabulary"
# "word '9600' not in vocabulary"
# "word 'gdasus' not in vocabulary"
# "word '295' not in vocabulary"
# "word '878' not in vocabulary"
# "word '296' not in vocabulary"
# "word '610' not in vocabulary"
# "word 'patrimoniodetodos' not in vocabulary"
# "word '219' not in vocabulary"
# "word '809' not in vocabulary"
# "word '340' not in vocabulary"
# "word 'prodirh' not in vocabulary"
# "word 'remocao' not in vocabulary"
# "word '507' not in vocabulary"
# "word '840' not in vocabulary"
# "word '012' not in vocabulary"
# "word '7o' not in vocabulary"
# "word '1071' not in vocabulary"
# "word '555' not in vocabulary"
# "word 'atendvirtual' not in vocabulary"
# "word 'defaultatendcertdigital' not in vocabulary"
# "word '270' not in vocabulary"
# "word '“o' not in vocabulary"
# "word 'formularioconsultamensagem' not in vocabulary"
# "word '311' not in vocabulary"
# "word 'servicosonline' not in vocabulary"
# "word '244' not in vocabulary"
# "word '919' not in vocabulary"
# "word 'destinaà' not in vocabulary"
# "word '185' not in vocabulary"
# "word 'internae' not in vocabulary"
# "word '316' not in vocabulary"
# "word '551' not in vocabulary"
# "word '3308' not in vocabulary"
# "word '239' not in vocabulary"
# "word 'cgcon' not in vocabulary"
# "word 'bpeq' not in vocabulary"
# "word 'cpii' not in vocabulary"
# "word 'dages' not in vocabulary"
# "word 'webp' not in vocabulary"
# "word 'rio2016' not in vocabulary"
# "word 'astec' not in vocabulary"
# "word 'nacircular' not in vocabulary"
# "word '971' not in vocabulary"
# "word '655' not in vocabulary"
# "word '283' not in vocabulary"
# "word '935' not in vocabulary"
# "word '268' not in vocabulary"
# "word '10h' not in vocabulary"
# "word '470' not in vocabulary"
# "word '594' not in vocabulary"
# "word '60035' not in vocabulary"
# "word '3810' not in vocabulary"
# "word '5198' not in vocabulary"
# "word '3223' not in vocabulary"
# "word '3993' not in vocabulary"
# "word '627' not in vocabulary"
# "word 'sepac' not in vocabulary"
# "word 'naquestão' not in vocabulary"
# "word 'indígenapassou' not in vocabulary"
# "word '691' not in vocabulary"
# "word 'napáginainstitucional' not in vocabulary"
# "word '480' not in vocabulary"
# "word '371' not in vocabulary"
# "word 'c2' not in vocabulary"
# "word '0104' not in vocabulary"
# "word '3329' not in vocabulary"
# "word '9068' not in vocabulary"
# "word 'internapara' not in vocabulary"
# "word '71000' not in vocabulary"
# "word '30h' not in vocabulary"
# "word 'mtpac' not in vocabulary"
# "word '474' not in vocabulary"
# "word '381' not in vocabulary"
# "word '113' not in vocabulary"
# "word 'l2' not in vocabulary"
# "word '009' not in vocabulary"
# "word 'nafaixa' not in vocabulary"
# "word '196' not in vocabulary"
# "word 'tabcad' not in vocabulary"
# "word 'nadiretoria' not in vocabulary"
# "word 'piic' not in vocabulary"
# "word '242' not in vocabulary"
# "word '133' not in vocabulary"
# "word '197' not in vocabulary"
# "word '358' not in vocabulary"
# "word '“previdência' not in vocabulary"
# "word 'social”' not in vocabulary"
# "word '“extrato' not in vocabulary"
# "word 'previdenciário”' not in vocabulary"
# "word '892' not in vocabulary"
# "word '973' not in vocabulary"
# "word 'ato2015' not in vocabulary"
# "word '564' not in vocabulary"
# "word '1970' not in vocabulary"
# "word 'a3p' not in vocabulary"
# "word '3°' not in vocabulary"
# "word '584' not in vocabulary"
# "word '3938' not in vocabulary"
# "word '078' not in vocabulary"
# "word 'naimpossibilidade' not in vocabulary"
# "word 'zonafranca' not in vocabulary"
# "word 'dipoa' not in vocabulary"
# "word 'psoríaca' not in vocabulary"
# "word 'ancilosante' not in vocabulary"
# "word 'siops' not in vocabulary"
# "word 'isper' not in vocabulary"
# "word '811' not in vocabulary"
# "word '245' not in vocabulary"
# "word '326' not in vocabulary"
# "word '867' not in vocabulary"
# "word '194' not in vocabulary"
# "word '626' not in vocabulary"
# "word '287' not in vocabulary"
# "word 'napne' not in vocabulary"
# "word 'nalai' not in vocabulary"
# "word '006' not in vocabulary"
# "word '727' not in vocabulary"
# "word 'gdpgpe' not in vocabulary"
# "word 'scdp' not in vocabulary"
# "word 'cgpae' not in vocabulary"
# "word '547' not in vocabulary"
# "word 'agrofit' not in vocabulary"
# "word 'dfpp' not in vocabulary"
# "word 'asfoc' not in vocabulary"
# "word '008' not in vocabulary"
# "word '3711' not in vocabulary"
# "word '07h' not in vocabulary"
# "word '199' not in vocabulary"
# "word '554' not in vocabulary"
# "word '298' not in vocabulary"
# "word '313' not in vocabulary"
# "word 'cgfse' not in vocabulary"
# "word '370' not in vocabulary"
# "word 'napesquisa' not in vocabulary"
# "word '3327' not in vocabulary"
# "word '3344' not in vocabulary"
# "word 'páginacontendo' not in vocabulary"
# "word '309' not in vocabulary"
# "word '9804' not in vocabulary"
# "word '529' not in vocabulary"
# "word '420' not in vocabulary"
# "word '258' not in vocabulary"
# "word 'naconta' not in vocabulary"
# "word '171' not in vocabulary"
# "word 'portaldab' not in vocabulary"
# "word '457' not in vocabulary"
# "word '845' not in vocabulary"
# "word '0876' not in vocabulary"
# "word '246' not in vocabulary"
# "word '174' not in vocabulary"
# "word '624' not in vocabulary"
# "word '430' not in vocabulary"
# "word '795' not in vocabulary"
# "word 'sisrgp' not in vocabulary"
# "word '377' not in vocabulary"
# "word '7998' not in vocabulary"
# "word '3370' not in vocabulary"
# "word '007' not in vocabulary"
# "word '587' not in vocabulary"
# "word 'suest' not in vocabulary"
# "word '3026' not in vocabulary"
# "word '20e' not in vocabulary"
# "word 'àquelas' not in vocabulary"
# "word '279' not in vocabulary"
# "word '906' not in vocabulary"
# "word '1974' not in vocabulary"
# "word '421' not in vocabulary"
# "word '201' not in vocabulary"
# "word '335' not in vocabulary"
# "word '7021111' not in vocabulary"
# "word 'ggmed' not in vocabulary"
# "word '3d' not in vocabulary"
# "word '99912' not in vocabulary"
# "word 'cosif' not in vocabulary"
# "word 'rjanrio' not in vocabulary"
# "word 'santanachamusca' not in vocabulary"
# "word 'cgpe' not in vocabulary"
# "word '203' not in vocabulary"
# "word '3182' not in vocabulary"
# "word 'coafe' not in vocabulary"
# "word '3448' not in vocabulary"
# "word 'nadivisão' not in vocabulary"
# "word '393' not in vocabulary"
# "word '341' not in vocabulary"
# "word 'dconf' not in vocabulary"
# "word '129' not in vocabulary"
# "word '00380' not in vocabulary"
# "word '065' not in vocabulary"
# "word '589' not in vocabulary"
# "word 'comunicacoes' not in vocabulary"
# "word 'deoc' not in vocabulary"
# "word 'tgwztc' not in vocabulary"
# "word 'ymbdqs' not in vocabulary"
# "word 'd5rytf' not in vocabulary"
# "word 'swmfek' not in vocabulary"
# "word '1000' not in vocabulary"
# "word '70047' not in vocabulary"
# "word 'napáginadesta' not in vocabulary"
# "word '3966' not in vocabulary"
# "word '1979' not in vocabulary"
# "word '1965' not in vocabulary"
# "word 'napró' not in vocabulary"
# "word '301' not in vocabulary"
# "word 'gpcon' not in vocabulary"
# "word '280' not in vocabulary"
# "word '864' not in vocabulary"
# "word 'getassi' not in vocabulary"
# "word '0800616161' not in vocabulary"
# "word '401' not in vocabulary"
# "word '3885' not in vocabulary"
# "word '1762' not in vocabulary"
# "word '682' not in vocabulary"
# "word '107' not in vocabulary"
# "word 'graduacao' not in vocabulary"
# "word 'dapes' not in vocabulary"
# "word '36036' not in vocabulary"
# "word 'naamazônia' not in vocabulary"
# "word '3899' not in vocabulary"
# "word 'laborada' not in vocabulary"
# "word '963' not in vocabulary"
# "word 'nacontratação' not in vocabulary"
# "word '183' not in vocabulary"
# "word 'naativa' not in vocabulary"
# "word '942' not in vocabulary"
# "word '165' not in vocabulary"
# "word 'indígenaou' not in vocabulary"
# "word 'gabdpgf' not in vocabulary"
# "word '2031' not in vocabulary"
# "word '650' not in vocabulary"
# "word '890' not in vocabulary"
# "word '707' not in vocabulary"
# "word 'nafonte' not in vocabulary"
# "word '83o' not in vocabulary"
# "word 'sispes' not in vocabulary"
# "word 'huab' not in vocabulary"
# "word 'gepac' not in vocabulary"
# "word '3359' not in vocabulary"
# "word '676' not in vocabulary"
# "word 'nanota' not in vocabulary"
# "word '3643' not in vocabulary"
# "word '“unidades' not in vocabulary"
# "word 'atendimento“' not in vocabulary"
# "word '762' not in vocabulary"
# "word '437' not in vocabulary"
# "word '815' not in vocabulary"
# "word '186' not in vocabulary"
# "word '12345678' not in vocabulary"
# "word 'www5' not in vocabulary"
# "word 'fapex' not in vocabulary"
# "word 'fiscalizacao' not in vocabulary"
# "word '272' not in vocabulary"
# "word '690' not in vocabulary"
# "word 'cgimp' not in vocabulary"
# "word '209' not in vocabulary"
# "word '848' not in vocabulary"
# "word '874' not in vocabulary"
# "word 'fosfoetanolaminasintética' not in vocabulary"
# "word 'consignamos' not in vocabulary"
# "word '3529' not in vocabulary"
# "word 'g20' not in vocabulary"
# "word 'investidorpetrobras' not in vocabulary"
# "word 'diahv' not in vocabulary"
# "word 'ppgci' not in vocabulary"
# "word 'siacco' not in vocabulary"
# "word 'dlsp' not in vocabulary"
# "word 'artemeter' not in vocabulary"
# "word '20mg' not in vocabulary"
# "word 'lumefantrine' not in vocabulary"
# "word '120mg' not in vocabulary"
# "word '23038' not in vocabulary"
# "word '1946' not in vocabulary"
# "word '1932' not in vocabulary"
# "word 'cgfop' not in vocabulary"
# "word 'siasg' not in vocabulary"
# "word '096' not in vocabulary"
# "word '408' not in vocabulary"
# "word '960' not in vocabulary"
# "word '259' not in vocabulary"
# "word 'páginawww' not in vocabulary"
# "word '750' not in vocabulary"
# "word '440' not in vocabulary"
# "word '406' not in vocabulary"
# "word 'rreo' not in vocabulary"
# "word '21000' not in vocabulary"
# "word '1795' not in vocabulary"
# "word '974' not in vocabulary"
# "word 'naocasião' not in vocabulary"
# "word '644' not in vocabulary"
# "word '680' not in vocabulary"
# "word 'sudeg' not in vocabulary"
# "word '399' not in vocabulary"
# "word 'censo2010' not in vocabulary"
# "word '782' not in vocabulary"
# "word '817' not in vocabulary"
# "word 'páginahttp' not in vocabulary"
# "word '396' not in vocabulary"
# "word '002566' not in vocabulary"
# "word '08006448001' not in vocabulary"
# "word 'propesp' not in vocabulary"
# "word 'pfvs' not in vocabulary"
# "word '151' not in vocabulary"
# "word 'cgcp2' not in vocabulary"
# "word '502' not in vocabulary"
# "word '355' not in vocabulary"
# "word '288' not in vocabulary"
# "word '869' not in vocabulary"
# "word '467' not in vocabulary"
# "word '3410' not in vocabulary"
# "word 'cgpol' not in vocabulary"
# "word '1a' not in vocabulary"
# "word '175' not in vocabulary"
# "word 'gsiste' not in vocabulary"
# "word '8°' not in vocabulary"
# "word '3237' not in vocabulary"
# "word '293' not in vocabulary"
# "word 'cglic' not in vocabulary"
# "word 'nabahia' not in vocabulary"
# "word '2473' not in vocabulary"
# "word 'nanegativa' not in vocabulary"
# "word '70046' not in vocabulary"
# "word '806' not in vocabulary"
# "word '842' not in vocabulary"
# "word '905' not in vocabulary"
# "word '909' not in vocabulary"
# "word '2192' not in vocabulary"
# "word 'nalocalidade' not in vocabulary"
# "word 'perquirido' not in vocabulary"
# "word 'ddgp' not in vocabulary"
# "word '4709' not in vocabulary"
# "word 'dantps' not in vocabulary"
# "word 'divisão”' not in vocabulary"
# "word 'nainformação' not in vocabulary"
# "word '214' not in vocabulary"
# "word '728' not in vocabulary"
# "word '3214' not in vocabulary"
# "word 'facilitacao' not in vocabulary"
# "word '253' not in vocabulary"
# "word '3700' not in vocabulary"
# "word 'concessoes' not in vocabulary"
# "word 'qrstae' not in vocabulary"
# "word 'cgpli' not in vocabulary"
# "word '3229' not in vocabulary"
# "word '803' not in vocabulary"
# "word '6594' not in vocabulary"
# "word '26º' not in vocabulary"
# "word 'urbanizacao' not in vocabulary"
# "word 'siurbn' not in vocabulary"
# "word 'ptei' not in vocabulary"
# "word 's2id' not in vocabulary"
# "word 'dataescolabrasil' not in vocabulary"
# "word 'drca' not in vocabulary"
# "word 'dfanbsb' not in vocabulary"
# "word '423' not in vocabulary"
# "word 'cgrat' not in vocabulary"
# "word '645' not in vocabulary"
# "word '225' not in vocabulary"
# "word '747' not in vocabulary"
# "word '291' not in vocabulary"
# "word '694' not in vocabulary"
# "word '495' not in vocabulary"
# "word 'portalbb' not in vocabulary"
# "word 'htms' not in vocabulary"
# "word '407' not in vocabulary"
# "word 'naufg' not in vocabulary"
# "word 'páginadedicada' not in vocabulary"
# "word 'propg' not in vocabulary"
# "word '046' not in vocabulary"
# "word '907' not in vocabulary"
# "word 'ananão' not in vocabulary"
# "word 'naatenção' not in vocabulary"
# "word '1181' not in vocabulary"
# "word '472' not in vocabulary"
# "word 'governanca' not in vocabulary"
# "word '397' not in vocabulary"
# "word '950' not in vocabulary"
# "word 'calinamafra' not in vocabulary"
# "word '1977' not in vocabulary"
# "word '2027' not in vocabulary"
# "word '9039' not in vocabulary"
# "word 'menumercado' not in vocabulary"
# "word 'cadastrocorretores' not in vocabulary"
# "word 'acessoconsultacorretores' not in vocabulary"
# "word '30mb' not in vocabulary"
# "word 'demonstracoes' not in vocabulary"
# "word 'internacedidos' not in vocabulary"
# "word '861' not in vocabulary"
# "word '017' not in vocabulary"
# "word 'autorizacoes' not in vocabulary"
# "word '528' not in vocabulary"
# "word 'nº25820' not in vocabulary"
# "word '266' not in vocabulary"
# "word '977' not in vocabulary"
# "word '841' not in vocabulary"
# "word '274' not in vocabulary"
# "word 'sfg' not in vocabulary"
# "word 'vantajosidade' not in vocabulary"
# "word '2498' not in vocabulary"
# "word '018' not in vocabulary"
# "word 'scmed' not in vocabulary"
# "word 'naobtenção' not in vocabulary"
# "word 'cmar' not in vocabulary"
# "word '060' not in vocabulary"
# "word 'naloa' not in vocabulary"
# "word 'nusel' not in vocabulary"
# "word 'mdcr' not in vocabulary"
# "word '700' not in vocabulary"
# "word '1500' not in vocabulary"
# "word 'diope' not in vocabulary"
# "word 'naans' not in vocabulary"
# "word 'diurnadrl' not in vocabulary"
# "word '390' not in vocabulary"
# "word 'ccont' not in vocabulary"
# "word 'nadependência' not in vocabulary"
# "word '1962' not in vocabulary"
# "word '615' not in vocabulary"
# "word 'orcamentobrasil' not in vocabulary"
# "word 'prodist' not in vocabulary"
# "word 'fundahc' not in vocabulary"
# "word '980' not in vocabulary"
# "word '910' not in vocabulary"
# "word '308' not in vocabulary"
# "word '812' not in vocabulary"
# "word '022' not in vocabulary"
# "word '783' not in vocabulary"
# "word '027' not in vocabulary"
# "word '850' not in vocabulary"
# "word 'vianaequipe' not in vocabulary"
# "word '083' not in vocabulary"
# "word '550' not in vocabulary"
# "word 'sugep' not in vocabulary"
# "word 'nacitada' not in vocabulary"
# "word 'integradorrhc' not in vocabulary"
# "word '387' not in vocabulary"
# "word 'pndpa' not in vocabulary"
# "word 'atbhe' not in vocabulary"
# "word 'viverseguro' not in vocabulary"
# "word '778' not in vocabulary"
# "word 'cpads' not in vocabulary"
# "word '513' not in vocabulary"
# "word '475' not in vocabulary"
# "word 'fumian' not in vocabulary"
# "word '1121' not in vocabulary"
# "word '452' not in vocabulary"
# "word 'miccione' not in vocabulary"
# "word 'snear' not in vocabulary"
# "word '385' not in vocabulary"
# "word 'napós' not in vocabulary"
# "word '038' not in vocabulary"
# "word 'naintranet' not in vocabulary"
# "word 'naredistribuição' not in vocabulary"
# "word '738' not in vocabulary"
# "word '858' not in vocabulary"
# "word 'prestacao' not in vocabulary"
# "word 'inspecao' not in vocabulary"
# "word '5140' not in vocabulary"
# "word 'gdace' not in vocabulary"
# "word '328' not in vocabulary"
# "word 'vipos' not in vocabulary"
# "word '426' not in vocabulary"
# "word '09013' not in vocabulary"
# "word '000102' not in vocabulary"
# "word 'ciinfo' not in vocabulary"
# "word '512' not in vocabulary"
# "word '429' not in vocabulary"
# "word '“a”' not in vocabulary"
# "word 'cggti' not in vocabulary"
# "word 'nacvm' not in vocabulary"
# "word 'geout' not in vocabulary"
# "word 'snsa' not in vocabulary"
# "word 'diarq' not in vocabulary"
# "word '353' not in vocabulary"
# "word '364' not in vocabulary"
# "word '74550' not in vocabulary"
# "word '74630' not in vocabulary"
# "word '74710' not in vocabulary"
# "word '68820' not in vocabulary"
# "word '68900' not in vocabulary"
# "word '69040' not in vocabulary"
# "word 'cadprev' not in vocabulary"
# "word 'sadipem' not in vocabulary"
# "word 'dsic' not in vocabulary"
# "word 'neab' not in vocabulary"
# "word '20296599' not in vocabulary"
# "word '302' not in vocabulary"
# "word '591' not in vocabulary"
# "word '986' not in vocabulary"
# "word '853' not in vocabulary"
# "word '807' not in vocabulary"
# "word '243' not in vocabulary"
# "word 'tornaa' not in vocabulary"
# "word '852' not in vocabulary"
# "word '222' not in vocabulary"
# "word '428' not in vocabulary"
# "word 'internaou' not in vocabulary"
# "word '3366' not in vocabulary"
# "word 'm2' not in vocabulary"
# "word '306' not in vocabulary"
# "word 'naocorrência' not in vocabulary"
# "word '362' not in vocabulary"
# "word '071' not in vocabulary"
# "word '375' not in vocabulary"
# "word '670' not in vocabulary"
# "word 'vianacampos' not in vocabulary"
# "word 'copad' not in vocabulary"
# "word 'bbtur' not in vocabulary"
# "word '710' not in vocabulary"
# "word '264' not in vocabulary"
# "word 'semanaepidemiológica' not in vocabulary"
# "word 'internade' not in vocabulary"
# "word 'mozila' not in vocabulary"
# "word 'desid' not in vocabulary"
# "word '508' not in vocabulary"
# "word 'aceleracao' not in vocabulary"
# "word '2260' not in vocabulary"
# "word '12º' not in vocabulary"
# "word 'n°12' not in vocabulary"
# "word '“prezado' not in vocabulary"
# "word 'ggpaf' not in vocabulary"
# "word '3239' not in vocabulary"
# "word '28875' not in vocabulary"
# "word 'naexpectativa' not in vocabulary"
# "word '347' not in vocabulary"
# "word '154' not in vocabulary"
# "word '7rfb' not in vocabulary"
# "word '453' not in vocabulary"
# "word 'corex' not in vocabulary"
# "word '176' not in vocabulary"
# "word '70056' not in vocabulary"
# "word '3356' not in vocabulary"
# "word '1340' not in vocabulary"
# "word '1888' not in vocabulary"
# "word 'dipes' not in vocabulary"
# "word '5037' not in vocabulary"
# "word '571' not in vocabulary"
# "word '13h30' not in vocabulary"
# "word 'homologatórias' not in vocabulary"
# "word 'listaservidores' not in vocabulary"
# "word '00123' not in vocabulary"
# "word 'moysa' not in vocabulary"
# "word '3309' not in vocabulary"
# "word 'elianaventorini' not in vocabulary"
# "word 'qrst' not in vocabulary"
# "word '15º' not in vocabulary"
# "word '“em' not in vocabulary"
# "word '323' not in vocabulary"
# "word 'napergunta' not in vocabulary"
# "word '3441' not in vocabulary"
# "word '9450' not in vocabulary"
# "word '483' not in vocabulary"
# "word 'cgpes' not in vocabulary"
# "word 'naufpr' not in vocabulary"
# "word '3221' not in vocabulary"
# "word '9933' not in vocabulary"
# "word '6250' not in vocabulary"
# "word '3132' not in vocabulary"
# "word '7353' not in vocabulary"
# "word 'diplan' not in vocabulary"
# "word '351' not in vocabulary"
# "word '488' not in vocabulary"
# "word 'estipulantes' not in vocabulary"
# "word '20071' not in vocabulary"
# "word '01049' not in vocabulary"
# "word '70093' not in vocabulary"
# "word '816' not in vocabulary"
# "word '312' not in vocabulary"
# "word 'sisg' not in vocabulary"
# "word '914' not in vocabulary"
# "word '773' not in vocabulary"
# "word '064' not in vocabulary"
# "word 'ccjs' not in vocabulary"
# ...
# "word '31076024' not in vocabulary"
# "word '5803' not in vocabulary"
# "word 'ceppac' not in vocabulary"
# "word '23480018099201531' not in vocabulary"
# "word '0800618080' not in vocabulary"
# "word 'microstrategy' not in vocabulary"
# "word 'página297' not in vocabulary"
# "word 'páginaespecífica' not in vocabulary"
# "word '3116' not in vocabulary"
# "word '7681' not in vocabulary"
# "word 'cgnac' not in vocabulary"
# "word 'pibiti' not in vocabulary"
# "word 'cnpb' not in vocabulary"
# "word '32119150' not in vocabulary"
# "word 'cgapb' not in vocabulary"
# "word '32119942' not in vocabulary"
# "word 'wrege' not in vocabulary"
# "word '277' not in vocabulary"
# "word 'indígenambya' not in vocabulary"
# "word 'guajayvi' not in vocabulary"
# "word 'pequenaka' not in vocabulary"
# "word 'aguy' not in vocabulary"
# "word 'es001' not in vocabulary"
# "word 'es005' not in vocabulary"
# "word 'es006' not in vocabulary"
# "word 'in056' not in vocabulary"
# "word 'in024' not in vocabulary"
# "word 'in046' not in vocabulary"
# "word 'in016' not in vocabulary"
# "word 'urbanaresidente' not in vocabulary"
# "word 'carrogi' not in vocabulary"
# "word 'viannagerência' not in vocabulary"
# "word 'pbio' not in vocabulary"
# "word '4600316288' not in vocabulary"
# "word '85ª' not in vocabulary"
# "word '86ª' not in vocabulary"
# "word '23480021389201723' not in vocabulary"
# "word '23480017332201568' not in vocabulary"
# "word 'djcn' not in vocabulary"
# "word '23480008158201643' not in vocabulary"
# "word ''dgp' not in vocabulary"
# "word 'br'' not in vocabulary"
# "word '07530' not in vocabulary"
# "word 'superacao' not in vocabulary"
# "word 'hotsitespetrobras' not in vocabulary"
# "word 'nmofupr' not in vocabulary"
# "word 'nmofute' not in vocabulary"
# "word 'nacter' not in vocabulary"
# "word 'nmoter' not in vocabulary"
# "word '001170' not in vocabulary"
# "word '01390000641201737' not in vocabulary"
# "word 'reginaheck' not in vocabulary"
# "word '23480012543201512' not in vocabulary"
# "word '000534' not in vocabulary"
# "word 'renavans' not in vocabulary"
# "word '7831' not in vocabulary"
# "word '526256214' not in vocabulary"
# "word '7821' not in vocabulary"
# "word '526254602' not in vocabulary"
# "word '5661' not in vocabulary"
# "word '841919089' not in vocabulary"
# "word '6701' not in vocabulary"
# "word '456400486' not in vocabulary"
# "word '6731' not in vocabulary"
# "word '456399291' not in vocabulary"
# "word '9461' not in vocabulary"
# "word '450002365' not in vocabulary"
# "word '9441' not in vocabulary"
# "word '450221142' not in vocabulary"
# "word '99903000174201712' not in vocabulary"
# "word 'napáginatransparência' not in vocabulary"
# "word 'conselheirolafaiete' not in vocabulary"
# "word 'servicosdoservidor' not in vocabulary"
# "word '008295' not in vocabulary"
# "word '23480022543201601' not in vocabulary"
# "word '000802' not in vocabulary"
# "word 'dgsa' not in vocabulary"
# "word '1424' not in vocabulary"
# "word '98403' not in vocabulary"
# "word '9502' not in vocabulary"
# "word 'eletrobrasroraima' not in vocabulary"
# "word '1357' not in vocabulary"
# "word '23480008180201693' not in vocabulary"
# "word 'recrutamentoe' not in vocabulary"
# "word 'semanasegunda' not in vocabulary"
# "word 'estudenauffs' not in vocabulary"
# "word 'satisfativa”' not in vocabulary"
# "word '23480008816201788' not in vocabulary"
# "word '002062' not in vocabulary"
# "word '1672' not in vocabulary"
# "word '84055' not in vocabulary"
# "word 'fd26e741a9' not in vocabulary"
# "word 'telemakos' not in vocabulary"
# "word 'gandash' not in vocabulary"
# "word '03000001167' not in vocabulary"
# "word 'posgraduacao' not in vocabulary"
# "word 'gedep' not in vocabulary"
# "word '1023432' not in vocabulary"
# "word '99901001659201743' not in vocabulary"
# "word '50606' not in vocabulary"
# "word '002206' not in vocabulary"
# "word '000217' not in vocabulary"
# "word 'páginaconforme' not in vocabulary"
# "word '6600' not in vocabulary"
# "word 'refrigeracao' not in vocabulary"
# "word 'qualityatacado' not in vocabulary"
# "word 'lipcomercial' not in vocabulary"
# "word 'reciclaqui' not in vocabulary"
# "word 'bringit' not in vocabulary"
# "word 'tchetoner' not in vocabulary"
# "word 'rafaelcamposmendes' not in vocabulary"
# "word 'njvglobal' not in vocabulary"
# "word 'maximqualitta' not in vocabulary"
# "word 'fifbelchior' not in vocabulary"
# "word 'enzoparceria' not in vocabulary"
# "word 'casadocartuchoinga' not in vocabulary"
# "word 'artsupri' not in vocabulary"
# "word 'kdatacadista' not in vocabulary"
# "word 'jairvitorino2' not in vocabulary"
# "word 'ktecdobrasil' not in vocabulary"
# "word 'rozelaine' not in vocabulary"
# "word 'planetgraf' not in vocabulary"
# "word 'rmalucelli' not in vocabulary"
# "word 'graficaipe' not in vocabulary"
# "word 'vendas3' not in vocabulary"
# "word 'cseletro' not in vocabulary"
# "word 'tlcartuchos' not in vocabulary"
# "word 'connectpartner' not in vocabulary"
# "word 'jlcomercio' not in vocabulary"
# "word 'gclitecnologia' not in vocabulary"
# "word 'zba' not in vocabulary"
# "word 'compulinea' not in vocabulary"
# "word 'vendasonlinecomercial' not in vocabulary"
# "word 'suporte1' not in vocabulary"
# "word 'netpar' not in vocabulary"
# "word 'fnalmeidacialtda' not in vocabulary"
# "word 'wjcomercial' not in vocabulary"
# "word 'camposemenezes' not in vocabulary"
# "word 'm2etiquetas' not in vocabulary"
# "word 'flashcomercio' not in vocabulary"
# "word 'ligliginformatica' not in vocabulary"
# "word 'dfcartuchos' not in vocabulary"
# "word 'ciadocartuchobh' not in vocabulary"
# "word 'ensautomotiva' not in vocabulary"
# "word 'informatic' not in vocabulary"
# "word 'districomp' not in vocabulary"
# "word 'emersonm' not in vocabulary"
# "word 'comercial3' not in vocabulary"
# "word 'warano' not in vocabulary"
# "word 'kiver' not in vocabulary"
# "word 'etibras' not in vocabulary"
# "word 'compuset' not in vocabulary"
# "word 'ebarbosasouza' not in vocabulary"
# "word 'greendata' not in vocabulary"
# "word 'danthaw' not in vocabulary"
# "word 'apolocomercial' not in vocabulary"
# "word 'abntoner' not in vocabulary"
# "word 'mvlicitacao' not in vocabulary"
# "word 'ialves2n' not in vocabulary"
# "word 'distribuidorajr26' not in vocabulary"
# "word 'damasotecnologia' not in vocabulary"
# "word 'techtronicsdobrasil' not in vocabulary"
# "word 'jambsbdf' not in vocabulary"
# "word 'gmcomp' not in vocabulary"
# "word 'zappcomercio' not in vocabulary"
# "word 'phdcomercio' not in vocabulary"
# "word 'grupocsdobrasil' not in vocabulary"
# "word 'gigabytebsb' not in vocabulary"
# "word 'argsdistribuidora' not in vocabulary"
# "word 'caravella2000' not in vocabulary"
# "word 'mjr' not in vocabulary"
# "word 'licitacaoblueparts' not in vocabulary"
# "word 'pcsuprimentos' not in vocabulary"
# "word 'cawitec' not in vocabulary"
# "word 'governocompras' not in vocabulary"
# "word 'bohrersound' not in vocabulary"
# "word 'solonetwork' not in vocabulary"
# "word 'imperialsuprimentos' not in vocabulary"
# "word 'idealdistribuidora' not in vocabulary"
# "word 'mtrdistribuidora' not in vocabulary"
# "word 'amintasmg' not in vocabulary"
# "word 'tubaraosoftware' not in vocabulary"
# "word 'cursosweb' not in vocabulary"
# "word 'bastos90' not in vocabulary"
# "word 'jvstecnologia' not in vocabulary"
# "word 'maikeconstantino' not in vocabulary"
# "word 'nsdistribuidoraalves' not in vocabulary"
# "word 'comercialeservicos' not in vocabulary"
# "word 'jmrdistribuidoradobrasiil' not in vocabulary"
# "word 'distriprb' not in vocabulary"
# "word 'totalsuprimentos' not in vocabulary"
# "word 'amamelis' not in vocabulary"
# "word 'vendas1' not in vocabulary"
# "word 'prorege' not in vocabulary"
# "word 'reprografcomercial' not in vocabulary"
# "word 'comercialtrxvendas2' not in vocabulary"
# "word 'corbagrafica' not in vocabulary"
# "word 'repremig' not in vocabulary"
# "word 'digiteck' not in vocabulary"
# "word 'parainformatica' not in vocabulary"
# "word 'guaxinimlogistics' not in vocabulary"
# "word 'phdcon' not in vocabulary"
# "word 'lopesti' not in vocabulary"
# "word 'jrmarquesazevedo' not in vocabulary"
# "word 'laserprintcartuchos' not in vocabulary"
# "word 'simplific' not in vocabulary"
# "word 'wx2' not in vocabulary"
# "word 'setorsound' not in vocabulary"
# "word 'seventec' not in vocabulary"
# "word 'toplan' not in vocabulary"
# "word 'engetron' not in vocabulary"
# "word 'croicomputadores' not in vocabulary"
# "word 'goldendistribuidora' not in vocabulary"
# "word 'mabimperio' not in vocabulary"
# "word 'wpstec' not in vocabulary"
# "word 'rfidbrasil' not in vocabulary"
# "word 'ziulcomercioltda' not in vocabulary"
# "word 'boingcomercio' not in vocabulary"
# "word 'djcomercial3' not in vocabulary"
# "word 'africainformatica' not in vocabulary"
# "word 'mwdobrasil' not in vocabulary"
# "word 'bslcomercial' not in vocabulary"
# "word 'lecomercioeservicos' not in vocabulary"
# "word 'caiocesar' not in vocabulary"
# "word 'marcelosena99' not in vocabulary"
# "word 'aartebsb' not in vocabulary"
# "word 'officetek' not in vocabulary"
# "word 'gtdobrasil' not in vocabulary"
# "word 'maurilioamd' not in vocabulary"
# "word 'lemanopapeis' not in vocabulary"
# "word 'brasilboxcomercio' not in vocabulary"
# "word 'genaubrasil' not in vocabulary"
# "word 'fcguerreiro' not in vocabulary"
# "word 'cartuchos1000' not in vocabulary"
# "word 'onlineprintcartuchos' not in vocabulary"
# "word 'totalfornecimentos' not in vocabulary"
# "word 'condufibra' not in vocabulary"
# "word 'w3conectividade' not in vocabulary"
# "word 'supermicroinformatica' not in vocabulary"
# "word 'gmr2008' not in vocabulary"
# "word 'especializacao1' not in vocabulary"
# "word 'eped' not in vocabulary"
# "word '2240' not in vocabulary"
# "word '9528' not in vocabulary"
# "word '2220' not in vocabulary"
# "word 'pollianamoura' not in vocabulary"
# "word '23480017493201632' not in vocabulary"
# "word 'sisfiesportal' not in vocabulary"
# "word '12042016' not in vocabulary"
# "word '28043014' not in vocabulary"
# "word '000086' not in vocabulary"
# "word '22859597' not in vocabulary"
# "word '23480014001201576' not in vocabulary"
# "word 'organogramaifma' not in vocabulary"
# "word '000049' not in vocabulary"
# "word 'santanade' not in vocabulary"
# "word 'sipra' not in vocabulary"
# "word '23480017822201726' not in vocabulary"
# "word '23480022639' not in vocabulary"
# "word 'linl' not in vocabulary"
# "word 'ifetização' not in vocabulary"
# "word 'quiróptera' not in vocabulary"
# "word 'página133' not in vocabulary"
# "word 'fr2016' not in vocabulary"
# "word '1197' not in vocabulary"
# "word '23480023819201741' not in vocabulary"
# "word '12244' not in vocabulary"
# "word 'regiany' not in vocabulary"
# "word 'gerreira' not in vocabulary"
# "word '000278' not in vocabulary"
# "word '99944000008201730' not in vocabulary"
# "word '1113' not in vocabulary"
# "word '019891' not in vocabulary"
# "word '79209' not in vocabulary"
# "word 'ab165e6d85' not in vocabulary"
# "word '001467' not in vocabulary"
# "word '23480026819201701' not in vocabulary"
# "word '234800222782016' not in vocabulary"
# "word '1106' not in vocabulary"
# "word '1108' not in vocabulary"
# "word '980773' not in vocabulary"
# "word '000260' not in vocabulary"
# "word 'informação¹' not in vocabulary"
# "word '08623' not in vocabulary"
# "word '58750000258201689' not in vocabulary"
# "word '001267' not in vocabulary"
# "word 'passelivre' not in vocabulary"
# "word 'nº23480011285201620' not in vocabulary"
# "word '23480011285201620' not in vocabulary"
# "word 'ensalar' not in vocabulary"
# "word 'nasaída' not in vocabulary"
# "word '99901000182201789' not in vocabulary"
# "word 'crediserv' not in vocabulary"
# "word 'naago' not in vocabulary"
# "word '7448' not in vocabulary"
# "word '1701629998' not in vocabulary"
# "word '00700000520201609' not in vocabulary"
# "word '0826' not in vocabulary"
# "word 'hiscreweb' not in vocabulary"
# "word '20ocupados' not in vocabulary"
# "word '20vagos' not in vocabulary"
# "word '476279adi' not in vocabulary"
# "word '3599' not in vocabulary"
# "word '25483' not in vocabulary"
# "word '1863' not in vocabulary"
# "word '3768' not in vocabulary"
# "word '3104' not in vocabulary"
# "word '3437' not in vocabulary"
# "word '3964' not in vocabulary"
# "word '3510' not in vocabulary"
# "word '3330' not in vocabulary"
# "word '3772' not in vocabulary"
# "word '4048' not in vocabulary"
# "word '570177' not in vocabulary"
# "word '434059' not in vocabulary"
# "word '2649' not in vocabulary"
# "word '3388' not in vocabulary"
# "word '4033' not in vocabulary"
# "word '27516' not in vocabulary"
# "word '4086' not in vocabulary"
# "word '3999' not in vocabulary"
# "word '543974' not in vocabulary"
# "word '578543' not in vocabulary"
# "word '597368' not in vocabulary"
# "word '5758' not in vocabulary"
# "word '3545' not in vocabulary"
# "word '511961' not in vocabulary"
# "word '27875' not in vocabulary"
# "word '27931' not in vocabulary"
# "word '25347' not in vocabulary"
# "word '26064' not in vocabulary"
# "word '3243' not in vocabulary"
# "word '2727' not in vocabulary"
# "word '590880' not in vocabulary"
# "word '25493' not in vocabulary"
# "word '25284' not in vocabulary"
# "word '3944' not in vocabulary"
# "word '567110' not in vocabulary"
# "word '27840' not in vocabulary"
# "word '3952' not in vocabulary"
# "word '25943' not in vocabulary"
# "word '28279' not in vocabulary"
# "word '4465' not in vocabulary"
# "word '4264' not in vocabulary"
# "word '28141' not in vocabulary"
# "word '28003' not in vocabulary"
# "word '1923' not in vocabulary"
# "word '3386' not in vocabulary"
# "word '30260' not in vocabulary"
# "word '30272' not in vocabulary"
# "word '4277' not in vocabulary"
# "word '28816' not in vocabulary"
# "word '28102' not in vocabulary"
# "word '11243' not in vocabulary"
# "word '4357' not in vocabulary"
# "word '4372' not in vocabulary"
# "word '4425' not in vocabulary"
# "word '598099' not in vocabulary"
# "word '2650' not in vocabulary"
# "word '25870' not in vocabulary"
# "word '3184' not in vocabulary"
# "word '4543' not in vocabulary"
# "word '4661' not in vocabulary"
# "word '603583' not in vocabulary"
# "word '4568' not in vocabulary"
# "word '2404' not in vocabulary"
# "word '4078' not in vocabulary"
# "word '4578' not in vocabulary"
# "word '4638' not in vocabulary"
# "word '4424' not in vocabulary"
# "word '26860' not in vocabulary"
# "word '580963' not in vocabulary"
# "word '567985' not in vocabulary"
# "word '30585' not in vocabulary"
# "word '4430' not in vocabulary"
# "word '4795' not in vocabulary"
# "word '571969' not in vocabulary"
# "word '32033' not in vocabulary"
# "word '631389' not in vocabulary"
# "word '4822' not in vocabulary"
# "word '587371' not in vocabulary"
# "word '15342' not in vocabulary"
# "word '15106' not in vocabulary"
# "word '14996' not in vocabulary"
# "word '591797' not in vocabulary"
# "word '626307' not in vocabulary"
# "word '631363' not in vocabulary"
# "word '632212' not in vocabulary"
# "word '4976' not in vocabulary"
# "word '2036' not in vocabulary"
# "word '2621' not in vocabulary"
# "word '599176' not in vocabulary"
# "word '4947' not in vocabulary"
# "word '5020' not in vocabulary"
# "word '5028' not in vocabulary"
# "word '4963' not in vocabulary"
# "word '4965' not in vocabulary"
# "word '5130' not in vocabulary"
# "word '608482' not in vocabulary"
# "word '609381' not in vocabulary"
# "word '661256' not in vocabulary"
# "word '827833' not in vocabulary"
# "word '724347' not in vocabulary"
# "word '669069' not in vocabulary"
# "word '602381' not in vocabulary"
# "word '638115' not in vocabulary"
# "word '3127' not in vocabulary"
# "word '4204' not in vocabulary"
# "word '3943' not in vocabulary"
# "word '2680' not in vocabulary"
# "word '4679' not in vocabulary"
# "word '4747' not in vocabulary"
# "word '4923' not in vocabulary"
# "word '592581' not in vocabulary"
# "word '4227' not in vocabulary"
# "word '4333' not in vocabulary"
# "word '870947' not in vocabulary"
# "word '2390' not in vocabulary"
# "word '2386' not in vocabulary"
# "word '2397' not in vocabulary"
# "word '2859' not in vocabulary"
# "word '23457' not in vocabulary"
# "word '34110' not in vocabulary"
# "word '34122' not in vocabulary"
# "word '5062' not in vocabulary"
# "word '5065' not in vocabulary"
# "word '2159' not in vocabulary"
# "word 'narcl' not in vocabulary"
# "word '14872' not in vocabulary"
# "word 'naao' not in vocabulary"
# "word '2511' not in vocabulary"
# "word '33464' not in vocabulary"
# "word 'cgset' not in vocabulary"
# "word '99908000765201740' not in vocabulary"
# "word 'apcncapes' not in vocabulary"
# "word 'cgpp' not in vocabulary"
# "word '4546' not in vocabulary"
# "word '002287' not in vocabulary"

# %%
# Define model
def train_model(input_train, input_test, label_train, label_test,
                lstm_size=128, dropout=0.2, rec_dropout=0.2, lr=0.005, epochs=50, att_heads=4, max_length=128, 
                vocab_size=None, embed_size=None, emb_trainable=False, batch=128, early_stopping=5,
                save_dir="D:/resultados/checkpoins_solicitacao_keras_mh_att/", best_predefined_f1=0.390):

    # Time now
    now = datetime.now().strftime("%Y%m%d_%H%M%S")
    
    # Log
    log_dir = save_dir + now
    
    # Model Saver    
    if not os.path.exists(log_dir):
        os.makedirs(log_dir)
    
    log_file = open(os.path.join(log_dir,"log.txt"), mode="a")
    
    # Save Params
    params = {
        'lstm_size': lstm_size,
        'dropout': dropout,
        'rec_dropout': rec_dropout,
        'lr': lr,
        'epochs': epochs,
        'att_heads': att_heads,
        'max_length': max_length,
        'vocab_size': vocab_size,
        'embed_size': embed_size,
        'emb_trainable': emb_trainable,
        'batch': batch,
        'early_stopping': early_stopping,
        'log_dir': log_dir,
        'best_predefined_f1': best_predefined_f1}
    
    # Saving Parameters
    with open(os.path.join(log_dir, 'params.txt'),'a') as f:
        f.write('\n\n' + ('#'*60))
        f.write('\nParameters:\n')
        f.write('now: ' + str(now))
        f.write('\n' + dumps(params) + '\n')
    
    # input
    inp = Input(shape=(max_length, ))

    # Embedding layer - https://keras.io/layers/embeddings/
    embedding_layer = Embedding(vocab_size,
                                embed_size,                                
                                weights=[embedding_matrix],
                                input_length=max_length,
                                trainable=emb_trainable,
                                name='Embedding')(inp)

    # Bidirectional Layer
    bilstm_layer = Bidirectional(LSTM(
                        units=lstm_size,
                        return_sequences=True,
                        dropout=dropout,
                        recurrent_dropout=rec_dropout,
                        name='LSTM'))(embedding_layer)    

    # MultiHead-Attention Layer
    #https://pypi.org/project/keras-multi-head/
    multiHead_att_layer = MultiHeadAttention(head_num=att_heads, name='Multi-Head-Attention')(bilstm_layer)

    dropout_intermed_layer = Dropout(0.5)(multiHead_att_layer)

    # # Flatten
    flatten_layer = Flatten(name='Flatten')(dropout_intermed_layer)

    dense_intermed_layer = Dense(128, activation='relu')(flatten_layer)
    dropout_intermed_2_layer = Dropout(dropout)(dense_intermed_layer)

    # # # # Dense Layer
    if binary:
        dense_layer = Dense(1, activation='sigmoid')(dense_intermed_layer)    
    else:
        dense_layer = Dense(num_labels, activation='softmax')(dense_intermed_layer)    
    
    model = Model(inputs=inp, outputs=dense_layer)
    # model.summary()
    
    # Compile
    model.compile(optimizer=Adam(lr=lr), loss='binary_crossentropy', metrics=['accuracy', precision_m, recall_m, f1_m])
    
    # callbacks
    es_callback = EarlyStopping(monitor='val_loss', patience=early_stopping, verbose=1, mode='min')
    
    # Fitting Model
    model.fit(input_train,
              label_train,
              epochs=epochs,
              batch_size=batch,
              validation_data=(input_test, label_test),
              verbose=0,
              callbacks=[es_callback])
    
    # PLOT LOSS
    plt.title('Loss')
    plt.plot(model.history.history['loss'], label='train')
    plt.plot(model.history.history['val_loss'], label='test')
    plt.legend()
    #plt.show();
    plt.savefig(os.path.join(log_dir,'Loss.png'))
    plt.close()
    
    # Classification
    y_pred = model.predict(input_test, batch_size=batch, verbose=1)
    y_pred_bool = np.argmax(y_pred, axis=1)
    
    if not binary:
        label_test = np.argmax(label_test.values, axis=1)
    
    # Metrics
    f1 = f1_score(label_test, y_pred_bool, average='weighted')
    print(f"Best Test F1-Score: {f1:.3f}")
    
    print("#"*60 + '\n', file=log_file)
    print(classification_report(label_test, y_pred_bool), file=log_file)
    print("#"*60+ '\n', file=log_file)
    
    # Flush log file
    log_file.flush()
    log_file.close()
    
    # Save final result
    with open(os.path.join(log_dir[:-16], 'output.txt'),'a') as f:
        f.write('\n\n')
        f.write(log_dir)
        f.write('\n')
        f.write(f"Best Test F1-Score: {f1:.3f}")
        
    # save model and architecture to single file
    if f1 > best_predefined_f1:
        model.save(os.path.join(log_dir, "model.h5"))
        print("Saved model to disk")

# %%
# Model Params
lstm_size_list = [256, 512]
dropout_list = [0.25, 0.5]
rec_dropout_list = [0.1, 0.25, 0.5]
lr_list = [1e-3, 5e-4, 1e-4, 5e-5, 5e-6]

all_params = [lstm_size_list] + [dropout_list] + [rec_dropout_list] + [lr_list]

for each in itertools.product(*all_params):    
    lstm_size, dropout, rec_dropout, lr = each
    
    # Params
    print('lstm_size: ' + str(lstm_size))
    print('\tdropout: ' + str(dropout))
    print('\trec_dropout: ' + str(rec_dropout))
    print('\tlr: ' + str(lr))
    
    # train
    train_model(input_train, input_test, label_train, label_test, lstm_size, dropout, rec_dropout, lr, epochs=50,
                att_heads=8, max_length=max_length, vocab_size=vocab_size, embed_size=embed_size, emb_trainable=False, batch=128,
                early_stopping=5, save_dir="D:/Outputs_Mestrado/resultados_Atendimento/checkpoins_resposta_keras_mh_att/",
                best_predefined_f1=0.42)
# Out:
# lstm_size: 256
# 	dropout: 0.25
# 	rec_dropout: 0.1
# 	lr: 0.001
# Epoch 00009: early stopping
# 2993/2993 [==============================] - 3s 1ms/step
# Best Test F1-Score: 0.357
# lstm_size: 256
# 	dropout: 0.25
# 	rec_dropout: 0.1
# 	lr: 0.0005
# Epoch 00013: early stopping
# 2993/2993 [==============================] - 3s 1ms/step
# Best Test F1-Score: 0.393
# lstm_size: 256
# 	dropout: 0.25
# 	rec_dropout: 0.1
# 	lr: 0.0001
# Epoch 00010: early stopping
# 2993/2993 [==============================] - 3s 1ms/step
# Best Test F1-Score: 0.371
# lstm_size: 256
# 	dropout: 0.25
# 	rec_dropout: 0.1
# 	lr: 5e-05
# Epoch 00014: early stopping
# 2993/2993 [==============================] - 3s 1ms/step
# Best Test F1-Score: 0.365
# lstm_size: 256
# 	dropout: 0.25
# 	rec_dropout: 0.1
# 	lr: 5e-06
# Epoch 00019: early stopping
# 2993/2993 [==============================] - 4s 1ms/step
# Best Test F1-Score: 0.372
# lstm_size: 256
# 	dropout: 0.25
# 	rec_dropout: 0.25
# 	lr: 0.001
# Epoch 00016: early stopping
# 2993/2993 [==============================] - 3s 1ms/step
# Best Test F1-Score: 0.389
# lstm_size: 256
# 	dropout: 0.25
# 	rec_dropout: 0.25
# 	lr: 0.0005
# Epoch 00013: early stopping
# 2993/2993 [==============================] - 4s 1ms/step
# Best Test F1-Score: 0.411
# lstm_size: 256
# 	dropout: 0.25
# 	rec_dropout: 0.25
# 	lr: 0.0001
# Epoch 00014: early stopping
# 2993/2993 [==============================] - 3s 1ms/step
# Best Test F1-Score: 0.392
# lstm_size: 256
# 	dropout: 0.25
# 	rec_dropout: 0.25
# 	lr: 5e-05
# Epoch 00015: early stopping
# 2993/2993 [==============================] - 3s 1ms/step
# Best Test F1-Score: 0.372
# lstm_size: 256
# 	dropout: 0.25
# 	rec_dropout: 0.25
# 	lr: 5e-06
# Epoch 00024: early stopping
# 2993/2993 [==============================] - 3s 1ms/step
# Best Test F1-Score: 0.391
# lstm_size: 256
# 	dropout: 0.25
# 	rec_dropout: 0.5
# 	lr: 0.001
# Epoch 00008: early stopping
# 2993/2993 [==============================] - 3s 1ms/step
# Best Test F1-Score: 0.400
# lstm_size: 256
# 	dropout: 0.25
# 	rec_dropout: 0.5
# 	lr: 0.0005
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# <ipython-input-18-fbc85a533dba> in <module>
#      20                 att_heads=8, max_length=max_length, vocab_size=vocab_size, embed_size=embed_size, emb_trainable=False, batch=128,
#      21                 early_stopping=5, save_dir="D:/Outputs_Mestrado/resultados_Atendimento/checkpoins_resposta_keras_mh_att/",
# ---> 22                 best_predefined_f1=0.42)
#
# <ipython-input-17-f8a6c5bbcdfe> in train_model(input_train, input_test, label_train, label_test, lstm_size, dropout, rec_dropout, lr, epochs, att_heads, max_length, vocab_size, embed_size, emb_trainable, batch, early_stopping, save_dir, best_predefined_f1)
#      94               validation_data=(input_test, label_test),
#      95               verbose=0,
# ---> 96               callbacks=[es_callback])
#      97
#      98     # PLOT LOSS
#
# ~\Anaconda3\envs\keras_env\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1237                                         steps_per_epoch=steps_per_epoch,
#    1238                                         validation_steps=validation_steps,
# -> 1239                                         validation_freq=validation_freq)
#    1240
#    1241     def evaluate(self,
#
# ~\Anaconda3\envs\keras_env\lib\site-packages\keras\engine\training_arrays.py in fit_loop(model, fit_function, fit_inputs, out_labels, batch_size, epochs, verbose, callbacks, val_function, val_inputs, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq)
#     194                     ins_batch[i] = ins_batch[i].toarray()
#     195
# --> 196                 outs = fit_function(ins_batch)
#     197                 outs = to_list(outs)
#     198                 for l, o in zip(out_labels, outs):
#
# ~\Anaconda3\envs\keras_env\lib\site-packages\tensorflow_core\python\keras\backend.py in __call__(self, inputs)
#    3725         value = math_ops.cast(value, tensor.dtype)
#    3726       converted_inputs.append(value)
# -> 3727     outputs = self._graph_fn(*converted_inputs)
#    3728
#    3729     # EagerTensor.numpy() will often make a copy to ensure memory safety.
#
# ~\Anaconda3\envs\keras_env\lib\site-packages\tensorflow_core\python\eager\function.py in __call__(self, *args, **kwargs)
#    1549       TypeError: For invalid positional/keyword argument combinations.
#    1550     """
# -> 1551     return self._call_impl(args, kwargs)
#    1552
#    1553   def _call_impl(self, args, kwargs, cancellation_manager=None):
#
# ~\Anaconda3\envs\keras_env\lib\site-packages\tensorflow_core\python\eager\function.py in _call_impl(self, args, kwargs, cancellation_manager)
#    1589       raise TypeError("Keyword arguments {} unknown. Expected {}.".format(
#    1590           list(kwargs.keys()), list(self._arg_keywords)))
# -> 1591     return self._call_flat(args, self.captured_inputs, cancellation_manager)
#    1592
#    1593   def _filtered_call(self, args, kwargs):
#
# ~\Anaconda3\envs\keras_env\lib\site-packages\tensorflow_core\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1690       # No tape is watching; skip to running the function.
#    1691       return self._build_call_outputs(self._inference_function.call(
# -> 1692           ctx, args, cancellation_manager=cancellation_manager))
#    1693     forward_backward = self._select_forward_and_backward_functions(
#    1694         args,
#
# ~\Anaconda3\envs\keras_env\lib\site-packages\tensorflow_core\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     543               inputs=args,
#     544               attrs=("executor_type", executor_type, "config_proto", config),
# --> 545               ctx=ctx)
#     546         else:
#     547           outputs = execute.execute_with_cancellation(
#
# ~\Anaconda3\envs\keras_env\lib\site-packages\tensorflow_core\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      65     else:
#      66       message = e.message
# ---> 67     six.raise_from(core._status_to_exception(e.code, message), None)
#      68   except TypeError as e:
#      69     keras_symbolic_tensors = [
#
# ~\Anaconda3\envs\keras_env\lib\site-packages\six.py in raise_from(value, from_value)
#
# ResourceExhaustedError:  OOM when allocating tensor with shape[65536,128] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[node gradients_11/dense_23/MatMul_grad/MatMul_1 (defined at C:\Users\arthu\Anaconda3\envs\keras_env\lib\site-packages\keras\backend\tensorflow_backend.py:3009) ]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#  [Op:__inference_keras_scratch_graph_193698]
#
# Function call stack:
# keras_scratch_graph
